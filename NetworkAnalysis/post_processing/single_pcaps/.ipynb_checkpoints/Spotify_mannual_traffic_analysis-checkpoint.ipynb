# %% [markdown]
# ## Process of analysing each PCAP file
# 1. Load the PCAP file
# 2. Convert it to JSON
# 3. Extract dns packets
# 4. Try to find IPs for which we don't have their endpoint names
# 5. Create a dictionary of {"fqdn": {"domain_name:"", "subdomain":"", "organization":"", "ATSes":"", "Party":""}}
# 6. Find organizations
#     6.1 using DDG's emtity list
#     6.2 mannualy look at WHOIS and crunchbaxe.com
# 7. Find ATSes
# 8. Find Parties
# 9. Create large dataframe for each packet

# %%
import utilities
from subprocess import call
from subprocess import check_call
import os, sys
import tldextract
import pandas as pd

# %% [markdown]
# ## 1. load traffic

# %%
base_out = "/home/c2/alexa/source/voice-assistant-central/NetworkAnalysis/post_processing/single_pcaps"
pcap = os.path.join(base_out, "data/spotify.pcapng")

# %% [markdown]
# ## 2. convert pcap to json

# %%
jsonFile = pcap + "-ENC-out.json"

# %%
cmd = ["tshark",
           "-o", "tcp.analyze_sequence_numbers:TRUE",
           "-o", "tcp.desegment_tcp_streams:TRUE",
           "-o", "http.desegment_body:TRUE",
           "-r", pcap, "-T", "json"]

with open(jsonFile, "wb") as jf:
    check_call(cmd, stdout=jf)

# %% [markdown]
# ## 3. DNS Resolutions

# %%
dns_resolutions = {}
pcap_name = pcap.split('/')[-1].split('.')[0]


network_json_dir = os.path.join(base_out, pcap_name+".pcap-ENC-out.json")
network_json = utilities.read_json(network_json_dir)

for i in range(len(network_json)):
    if network_json[i]["_source"]["layers"]["frame"]["frame.protocols"] == 'eth:ethertype:ip:udp:dns':
        answers_key = []
        if "Answers" in network_json[i]["_source"]["layers"]["dns"].keys():
            answers_key  = network_json[i]["_source"]["layers"]["dns"]["Answers"].keys()
            for key in answers_key:
                if "CNAME" in key:
                    #print("CNAME")
                    continue
                try:    
                    dns_a = network_json[i]["_source"]["layers"]["dns"]["Answers"][key]["dns.a"]
                    dns_name = network_json[i]["_source"]["layers"]["dns"]["Answers"][key]["dns.resp.name"]
                    dns_resolutions[dns_a] = dns_name
                except:
                    pass

# %%
dns_resolutions
# Out:
# {'3.218.65.123': 'fireoscaptiveportal.com',
#  '54.204.135.149': 'fireoscaptiveportal.com',
#  '54.197.100.100': 'fireoscaptiveportal.com',
#  '54.161.64.53': 'fireoscaptiveportal.com',
#  '18.215.2.115': 'fireoscaptiveportal.com',
#  '54.88.240.89': 'fireoscaptiveportal.com',
#  '34.200.157.175': 'fireoscaptiveportal.com',
#  '18.232.191.54': 'fireoscaptiveportal.com',
#  '54.80.61.15': 'acsechocaptiveportal.com',
#  '34.200.70.190': 'acsechocaptiveportal.com',
#  '184.73.222.134': 'acsechocaptiveportal.com',
#  '52.46.133.19': 'todo-ta-g7g.amazon.com',
#  '34.239.12.200': 'ntp-g7g.amazon.com',
#  '52.119.198.101': 'api.amazon.com',
#  '18.65.228.27': 'd1gsg05rq1vjdw.cloudfront.net',
#  '54.239.19.122': 'dss-na.amazon.com',
#  '18.65.229.79': 'ffs-provisioner-config.amazon-dss.com',
#  '18.65.229.68': 'ffs-provisioner-config.amazon-dss.com',
#  '18.65.229.40': 'ffs-provisioner-config.amazon-dss.com',
#  '18.65.229.129': 'ffs-provisioner-config.amazon-dss.com',
#  '72.21.195.82': 'dcape-na.amazon.com',
#  '18.65.227.128': 'd3p8zr0ffa9t17.cloudfront.net',
#  '18.65.227.15': 'd3p8zr0ffa9t17.cloudfront.net',
#  '18.65.227.74': 'd3p8zr0ffa9t17.cloudfront.net',
#  '18.65.227.111': 'd3p8zr0ffa9t17.cloudfront.net',
#  '142.251.46.228': 'www.google.com',
#  '142.251.46.163': 'connectivitycheck.gstatic.com',
#  '216.239.35.4': 'time.android.com',
#  '216.239.35.12': 'time.android.com',
#  '216.239.35.8': 'time.android.com',
#  '216.239.35.0': 'time.android.com',
#  '142.250.142.188': 'mobile-gtalk.l.google.com',
#  '176.32.101.52': 'bob-dispatch-prod-na.amazon.com',
#  '54.231.198.41': 's3-w.us-east-1.amazonaws.com',
#  '54.152.102.205': 'prod.amcs-tachyon.com',
#  '52.0.75.57': 'prod.amcs-tachyon.com',
#  '52.6.129.123': 'prod.amcs-tachyon.com',
#  '52.20.168.135': 'prod.amcs-tachyon.com',
#  '44.195.73.131': 'prod.amcs-tachyon.com',
#  '34.198.99.173': 'prod.amcs-tachyon.com',
#  '54.88.185.141': 'prod.amcs-tachyon.com',
#  '3.223.153.46': 'prod.amcs-tachyon.com',
#  '52.6.241.232': 'prod.amcs-tachyon.com',
#  '34.194.50.242': 'prod.amcs-tachyon.com',
#  '52.55.165.164': 'prod.amcs-tachyon.com',
#  '54.81.59.40': 'prod.amcs-tachyon.com',
#  '52.94.233.94': 'msh.amazon.com',
#  '34.117.13.189': 'cluster-web.meethue.com',
#  '18.235.228.160': 'ingestion.us-east-1.prod.arteries.alexa.a2z.com',
#  '54.84.197.105': 'ingestion.us-east-1.prod.arteries.alexa.a2z.com',
#  '34.200.164.136': 'ingestion.us-east-1.prod.arteries.alexa.a2z.com',
#  '52.5.70.131': 'ingestion.us-east-1.prod.arteries.alexa.a2z.com',
#  '3.225.36.244': 'ingestion.us-east-1.prod.arteries.alexa.a2z.com',
#  '3.221.217.227': 'ingestion.us-east-1.prod.arteries.alexa.a2z.com',
#  '18.65.227.169': 'dxz5jxhrrzigf.cloudfront.net',
#  '18.65.227.207': 'dxz5jxhrrzigf.cloudfront.net',
#  '18.65.227.87': 'dxz5jxhrrzigf.cloudfront.net',
#  '18.65.227.40': 'dxz5jxhrrzigf.cloudfront.net',
#  '52.216.241.108': 's3-w.us-east-1.amazonaws.com',
#  '52.217.232.193': 's3-w.us-east-1.amazonaws.com',
#  '52.94.224.149': 'dss-na.amazon.com',
#  '208.85.42.21': 'mediaserver-sv5-t1-1-v4v6.pandora.com',
#  '208.85.46.22': 't1-5.p-cdn.us',
#  '54.239.31.237': 'mlis.amazon.com',
#  '209.196.209.21': 't1-5.p-cdn.us',
#  '209.196.209.22': 't1-5.p-cdn.us',
#  '18.65.229.95': 'd2of0gfv69hsgh.cloudfront.net',
#  '18.65.229.98': 'd2of0gfv69hsgh.cloudfront.net',
#  '18.65.229.70': 'd2of0gfv69hsgh.cloudfront.net',
#  '18.65.229.45': 'd2of0gfv69hsgh.cloudfront.net',
#  '176.32.99.246': 'updates.amazon.com'}

# %% [markdown]
# ## 4. Find IPs for which dns map doesn't have corresponding name

# %%
no_name_ip_list = set()
for i in range(len(network_json)):
        if 'ip' in network_json[i]["_source"]["layers"].keys():
            ip_src = network_json[i]["_source"]["layers"]['ip']['ip.src']
            ip_dst = network_json[i]["_source"]["layers"]['ip']['ip.dst']
            
            if not ip_src.startswith('10.42') and not ip_src.startswith('255.255.'):
                if ip_src not in dns_resolutions:
                    no_name_ip_list.add(ip_src)
            
            if not ip_dst.startswith('10.42') and not ip_dst.startswith('255.255.'):
                if ip_dst not in dns_resolutions:
                    no_name_ip_list.add(ip_dst)
no_name_ip_list
# Out:
# {'0.0.0.0',
#  '224.0.0.22',
#  '224.0.0.251',
#  '239.255.255.250',
#  '54.239.18.66',
#  '8.8.8.8'}

# %%
dns_resolutions['54.239.18.66'] = "dss-na.amazon.com"
utilities.write_json(os.path.join(base_out, "dns_resolutions.json"), dns_resolutions)

# %% [markdown]
# ## 5. Creat a dictionary for fqdns in dns

# %%
dict_fqdns = {}
for ip, fqdn in dns_resolutions.items():
    if fqdn not in dict_fqdns:
        dict_fqdns[fqdn] = {'domain_name': '', 'SLD': '', 'subdomain' : '' ,'organization': '', 'ATSes': '', 'Party': ''}
        ext = tldextract.extract(fqdn)
        dict_fqdns[fqdn]['domain_name'] = ext.domain+"."+ext.suffix
        dict_fqdns[fqdn]['subdomain'] = ext.subdomain
        dict_fqdns[fqdn]['SLD'] = ext.domain
        dict_fqdns[fqdn]['organization'] = ""
        dict_fqdns[fqdn]['ATSes'] = ""
        dict_fqdns[fqdn]['Party'] = ""
dict_fqdns
# Out:
# {'fireoscaptiveportal.com': {'domain_name': 'fireoscaptiveportal.com',
#   'SLD': 'fireoscaptiveportal',
#   'subdomain': '',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'acsechocaptiveportal.com': {'domain_name': 'acsechocaptiveportal.com',
#   'SLD': 'acsechocaptiveportal',
#   'subdomain': '',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'todo-ta-g7g.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'todo-ta-g7g',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'ntp-g7g.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'ntp-g7g',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'api.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'api',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'd1gsg05rq1vjdw.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'd1gsg05rq1vjdw',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'dss-na.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'dss-na',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'ffs-provisioner-config.amazon-dss.com': {'domain_name': 'amazon-dss.com',
#   'SLD': 'amazon-dss',
#   'subdomain': 'ffs-provisioner-config',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'dcape-na.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'dcape-na',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'd3p8zr0ffa9t17.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'd3p8zr0ffa9t17',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'www.google.com': {'domain_name': 'google.com',
#   'SLD': 'google',
#   'subdomain': 'www',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'connectivitycheck.gstatic.com': {'domain_name': 'gstatic.com',
#   'SLD': 'gstatic',
#   'subdomain': 'connectivitycheck',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'time.android.com': {'domain_name': 'android.com',
#   'SLD': 'android',
#   'subdomain': 'time',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'mobile-gtalk.l.google.com': {'domain_name': 'google.com',
#   'SLD': 'google',
#   'subdomain': 'mobile-gtalk.l',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'bob-dispatch-prod-na.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'bob-dispatch-prod-na',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  's3-w.us-east-1.amazonaws.com': {'domain_name': 'amazonaws.com',
#   'SLD': 'amazonaws',
#   'subdomain': 's3-w.us-east-1',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'prod.amcs-tachyon.com': {'domain_name': 'amcs-tachyon.com',
#   'SLD': 'amcs-tachyon',
#   'subdomain': 'prod',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'msh.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'msh',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'cluster-web.meethue.com': {'domain_name': 'meethue.com',
#   'SLD': 'meethue',
#   'subdomain': 'cluster-web',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'ingestion.us-east-1.prod.arteries.alexa.a2z.com': {'domain_name': 'a2z.com',
#   'SLD': 'a2z',
#   'subdomain': 'ingestion.us-east-1.prod.arteries.alexa',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'dxz5jxhrrzigf.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'dxz5jxhrrzigf',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'mediaserver-sv5-t1-1-v4v6.pandora.com': {'domain_name': 'pandora.com',
#   'SLD': 'pandora',
#   'subdomain': 'mediaserver-sv5-t1-1-v4v6',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  't1-5.p-cdn.us': {'domain_name': 'p-cdn.us',
#   'SLD': 'p-cdn',
#   'subdomain': 't1-5',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'mlis.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'mlis',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'd2of0gfv69hsgh.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'd2of0gfv69hsgh',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''},
#  'updates.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'updates',
#   'organization': '',
#   'ATSes': '',
#   'Party': ''}}

# %% [markdown]
# ## 6. Find Organizations

# %%
ddg_entities = utilities.get_files_in_a_directory("/home/c2/alexa/post-processing/tracker-radar/entities")

for fqdn, details in dict_fqdns.items():
    for entity in ddg_entities:
        entity_content = utilities.read_json(entity)
        if details['domain_name'] in entity_content["properties"]:
            dict_fqdns[fqdn]['organization'] = entity_content["name"]
            break

# %%
not_found_organizations = set()
for fqdn, details in dict_fqdns.items():
    if len(details['organization']) == 0:
        not_found_organizations.add(details['domain_name'])

# %%
not_found_organizations
# Out:
# {'acsechocaptiveportal.com',
#  'amazon-dss.com',
#  'amcs-tachyon.com',
#  'fireoscaptiveportal.com'}

# %% [markdown]
# ### For organizations we didn't find on DDG, we use https://lookup.icann.org/lookup and crunchbase.com

# %%
manually_found_organs = {'acsechocaptiveportal.com' : 'Amazon Technologies, Inc.',
 'amazon-dss.com' : 'Amazon Technologies, Inc.',
 'amcs-tachyon.com' : 'Amazon Technologies, Inc.',
 'fireoscaptiveportal.com' : 'Amazon Technologies, Inc.'}

# %%
for fqdn, details in dict_fqdns.items():
    if len(details['organization']) == 0:
        details['organization'] = manually_found_organs[details['domain_name']]

# %%
for index, row in df.iterrows():
    if len(row['organization']) == 0:
        print(row['domain_name'])

# %% [markdown]
# ## 7. Find ATSes

# %%
filter_list_base = "/home/c2/alexa/source/voice-assistant-central/NetworkAnalysis/data/filter_lists/"
tracking = utilities.read_json(os.path.join(filter_list_base,"tracking", "tracking_list.json"))
advertising = utilities.read_json(os.path.join(filter_list_base, "advertising", "advertising_list.json"))

# %%
advertising
# Out:
# ['fireoscaptiveportal.com',
#  'opecloud.com',
#  '2leep.com',
#  '33across.com',
#  '365media.com',
#  '4info.com',
#  'adhaven.com',
#  '4mads.com',
#  'abaxinteractive.com',
#  'accelia.net',
#  'durasite.net',
#  'accordantmedia.com',
#  'mkt51.net',
#  'pages05.net',
#  'silverpop.com',
#  'vtrenz.net',
#  'acquisio.com',
#  'clickequations.net',
#  'actisens.com',
#  'gestionpub.com',
#  'activeconversion.com',
#  'activemeter.com',
#  'act-on.com',
#  'actonsoftware.com',
#  'acuity.com',
#  'acuityads.com',
#  'acuityplatform.com',
#  'ad2onegroup.com',
#  'ad4game.com',
#  'ad6media.fr',
#  'adabra.com',
#  'adality.de',
#  'adrtx.net',
#  'adaptiveads.com',
#  'adaptly.com',
#  'adaramedia.com',
#  'opinmind.com',
#  'yieldoptimizer.com',
#  'adatus.com',
#  'adbot.tw',
#  'adbrain.com',
#  'adbrn.com',
#  'adbrite.com',
#  'adbroker.de',
#  'ufpcdn.com',
#  'adchemy.com',
#  'adcirrus.com',
#  'a2dfp.net',
#  'addecisive.com',
#  'addgloo.com',
#  'addvantagemedia.com',
#  'addynamo.com',
#  'addynamo.net',
#  'adelphic.com',
#  'ipredictive.com',
#  'adengage.com',
#  'adeurope.com',
#  'adextent.com',
#  'adf.ly',
#  'adfonic.com',
#  'adforgeinc.com',
#  'adform.com',
#  'adform.net',
#  'adformdsp.net',
#  'seadform.net',
#  'adfox.ru',
#  'adfrontiers.com',
#  'adfunky.com',
#  'adfunkyserver.com',
#  'adfusion.com',
#  'adgainersolutions.com',
#  'adgear.com',
#  'adgrx.com',
#  'bloom-hq.com',
#  'runadtag.com',
#  'adgentdigital.com',
#  'shorttailmedia.com',
#  'adgibbon.com',
#  'adglare.com',
#  'adglare.net',
#  'adhood.com',
#  'adblade.com',
#  'adiant.com',
#  'adinsight.com',
#  'adinsight.eu',
#  'adiquity.com',
#  'adition.com',
#  'adjug.com',
#  'adjuggler.com',
#  'adjuggler.net',
#  'adjust.com',
#  'adkeeper.com',
#  'akncdn.com',
#  'adkernel.com',
#  'adknife.com',
#  'adknowledge.com',
#  'adparlor.com',
#  'bidsystem.com',
#  'cubics.com',
#  'lookery.com',
#  'adimg.net',
#  'adlantis.jp',
#  'adleave.com',
#  'adlibrium.com',
#  'adlucent.com',
#  'admagnet.com',
#  'admagnet.net',
#  'adman.gr',
#  'admarketplace.com',
#  'admarketplace.net',
#  'ampxchange.com',
#  'admarvel.com',
#  'admatrix.jp',
#  'ad-maven.com',
#  'agreensdistra.info',
#  'boudja.com',
#  'rensovetors.info',
#  'wrethicap.info',
#  'admaximizer.com',
#  'admedia.com',
#  'admedo.com',
#  'admeta.com',
#  'atemda.com',
#  'admicro.vn',
#  'vcmedia.vn',
#  'admixer.co.kr',
#  'admized.com',
#  'admobile.com',
#  'admotion.com',
#  'nspmotion.com',
#  'adnet.de',
#  'adnetik.com',
#  'wtp101.com',
#  'adnetwork.net',
#  'adnium.com',
#  'adnologies.com',
#  'heias.com',
#  '2o7.net',
#  'auditude.com',
#  'demdex.com',
#  'demdex.net',
#  'dmtracker.com',
#  'efrontier.com',
#  'everestads.net',
#  'everestjs.net',
#  'everesttech.net',
#  'hitbox.com',
#  'omniture.com',
#  'omtrdc.net',
#  'touchclarity.com',
#  'adocean-global.com',
#  'adocean.pl',
#  'adometry.com',
#  'dmtry.com',
#  'adomik.com',
#  'adonion.com',
#  'adop.cc',
#  'clickotmedia.com',
#  'adotmob.com',
#  'admission.net',
#  'adpdealerservices.com',
#  'cobalt.com',
#  'adpepper.com',
#  'adpepper.us',
#  'adperfect.com',
#  'adperium.com',
#  'adpersia.com',
#  'adprs.net',
#  'aprecision.net',
#  'adpredictive.com',
#  'adreactor.com',
#  'adrevolution.com',
#  'adriver.ru',
#  'adroll.com',
#  'adscale.de',
#  'adscience.nl',
#  'adserverpub.com',
#  'adshuffle.com',
#  'adside.com',
#  'doclix.com',
#  'adskeeper.co.uk',
#  'adskeeper.com',
#  'adspeed.com',
#  'adspeed.net',
#  'adsperity.com',
#  'adspirit.com',
#  'adspirit.de',
#  'adspirit.net',
#  'adsquare.com',
#  'adsrevenue.net',
#  'ad-stir.com',
#  'adstours.com',
#  'clickintext.net',
#  'adstune.com',
#  'adsty.com',
#  'adx1.com',
#  '4dsply.com',
#  'adsupply.com',
#  'adswizz.com',
#  'adtegrity.com',
#  'adtegrity.net',
#  'adtelligence.de',
#  'vertamedia.com',
#  'adthink.com',
#  'audienceinsights.net',
#  'adtiger.de',
#  'zadn.vn',
#  'adtruth.com',
#  'adultadworld.com',
#  'adultmoda.com',
#  'ad4m.at',
#  'ad4mat.de',
#  'adventive.com',
#  'adnext.fr',
#  'adverline.com',
#  'adv-adserver.com',
#  'adversal.com',
#  'adsmart.com',
#  'adverticum.com',
#  'adverticum.net',
#  'advertise.com',
#  'advertisespace.com',
#  'advertstream.com',
#  'advisormedia.cz',
#  'adworx.at',
#  'adworx.be',
#  'adworx.nl',
#  'adxpansion.com',
#  '00px.net',
#  'adxvalue.com',
#  'adxvalue.de',
#  'adyard.de',
#  'adyield.com',
#  'adyoulike.com',
#  'omnitagjs.com',
#  'pulpix.com',
#  'adzcentral.com',
#  'adzerk.com',
#  'adzerk.net',
#  'adzly.com',
#  'aemedia.com',
#  'bluestreak.com',
#  'aerifymedia.com',
#  'anonymous-media.com',
#  'affectv.co.uk',
#  'affili.net',
#  'affilinet-inside.de',
#  'banner-rotation.com',
#  'successfultogether.co.uk',
#  'affine.tv',
#  'affinesystems.com',
#  'affinity.com',
#  'afdads.com',
#  'afterdownload.com',
#  'aidata.io',
#  'aim4media.com',
#  'airpush.com',
#  'imiclk.com',
#  'albacross.com',
#  'allstarmediagroup.com',
#  'aloodo.com',
#  'altergeo.ru',
#  'amazon-adsystem.com',
#  'amazon.ca',
#  'amazon.co.jp',
#  'amazon.co.uk',
#  'amazon.de',
#  'amazon.es',
#  'amazon.fr',
#  'amazon.it',
#  'assoc-amazon.com',
#  'adnetwork.vn',
#  'ambientdigital.com.vn',
#  'adconion.com',
#  'amgdgt.com',
#  'amobee.com',
#  'euroclick.com',
#  'smartclip.com',
#  'turn.com',
#  'andbeyond.media',
#  'ansira.com',
#  'dsply.com',
#  'appcast.io',
#  'appenda.com',
#  'appflood.com',
#  'appier.com',
#  'appier.net',
#  'applifier.com',
#  'applovin.com',
#  'appsflyer.com',
#  'appssavvy.com',
#  'arkwrightshomebrew.com',
#  'ctasnet.com',
#  'atedra.com',
#  'hit-parade.com',
#  'affiliatetracking.com',
#  'atoomic.com',
#  'atrinsic.com',
#  'adlantic.nl',
#  'adnxs.com',
#  'adrdgt.com',
#  'alenty.com',
#  'appnexus.com',
#  'att.com',
#  'xandr.com',
#  'yp.com',
#  'audience2media.com',
#  'audienceadnetwork.com',
#  'audiencescience.com',
#  'revsci.net',
#  'targetingmarketplace.com',
#  'wunderloop.net',
#  'augme.com',
#  'hipcricket.com',
#  'augur.io',
#  'am.ua',
#  'autocentre.ua',
#  'pubmine.com',
#  'avalanchers.com',
#  'avantlink.com',
#  'adspdbl.com',
#  'avidglobalmedia.com',
#  'avidglobalmedia.eu',
#  'metadsp.co.uk',
#  'avocet.io',
#  'avsads.com',
#  'aweber.com',
#  'digitalwindow.com',
#  'dwin1.com',
#  'perfiliate.com',
#  'azetklik.sk',
#  'rsz.sk',
#  'backbeatmedia.com',
#  'bannerconnect.net',
#  'barilliance.com',
#  'baronsoffers.com',
#  'batanga.com',
#  'batanganetwork.com',
#  'beachfront.com',
#  'beanstockmedia.com',
#  'beencounter.com',
#  'begun.ru',
#  'adbutler.de',
#  'belboon.com',
#  'betgenius.com',
#  'connextra.com',
#  'betweendigital.com',
#  'bidfluence.com',
#  'bidr.io',
#  'bidswitch.net',
#  'mfadsrvr.com',
#  'bidtellect.com',
#  'bttrack.com',
#  'bidtheatre.com',
#  'bidvertiser.com',
#  'bgclck.me',
#  'xcvgdf.party',
#  'bigmir.net',
#  'binlayer.com',
#  'vendemore.com',
#  'bitcoinplus.com',
#  'bitmedia.io',
#  'bittads.com',
#  'bizo.com',
#  'bizographics.com',
#  'blacklabelads.com',
#  'blogcatalog.com',
#  'theblogfrog.com',
#  'blogher.com',
#  'blogherads.com',
#  'blogrollr.com',
#  'bkrtx.com',
#  'bluekai.com',
#  'tracksimple.com',
#  'blutrumpet.com',
#  'boo-box.com',
#  'boostbox.com.br',
#  'bounceexchange.com',
#  'bouncex.com',
#  'bouncex.net',
#  'brainient.com',
#  'brandaffinity.net',
#  'brandcrumb.com',
#  'brand.net',
#  'brandscreen.com',
#  'rtbidder.net',
#  'breaktime.com.tw',
#  'scupio.com',
#  'brightroll.com',
#  'btrll.com',
#  'brighttag.com',
#  'btstatic.com',
#  'thebrighttag.com',
#  'brilig.com',
#  'bucksense.com',
#  'burstly.com',
#  'burstbeacon.com',
#  'burstdirectads.com',
#  'burstmedia.com',
#  'burstnet.com',
#  'giantrealm.com',
#  'businessol.com',
#  'usebutton.com',
#  'beaconads.com',
#  'buysellads.com',
#  'buysight.com',
#  'permuto.com',
#  'pulsemgr.com',
#  'buzzparadise.com',
#  'bvmedia.ca',
#  'networldmedia.com',
#  'networldmedia.net',
#  'c1exchange.com',
#  'attributionmodel.com',
#  'c3metrics.com',
#  'c3tag.com',
#  'cadreon.com',
#  'campaigngrid.com',
#  'capitaldata.fr',
#  'carambo.la',
#  'caraytech.com.ar',
#  'e-planning.net',
#  'cart.ro',
#  'statistics.ro',
#  'carts.guru',
#  'casalemedia.com',
#  'medianet.com',
#  'cbproads.com',
#  'cedato.com',
#  'chango.ca',
#  'chango.com',
#  'channeladvisor.com',
#  'searchmarketing.com',
#  'channelintelligence.com',
#  'chartboost.com',
#  'checkm8.com',
#  'chitika.com',
#  'chitika.net',
#  'choicestream.com',
#  'choozle.com',
#  'clearlink.com',
#  'clearsaleing.com',
#  'csdata1.com',
#  'csdata2.com',
#  'csdata3.com',
#  'clearsearchmedia.com',
#  'csm-secure.com',
#  'clearsightinteractive.com',
#  'csi-tracking.com',
#  'clickaider.com',
#  'clickyab.com',
#  'adtoll.com',
#  'clickbooth.com',
#  'clickdimensions.com',
#  'clickdistrict.com',
#  'creative-serving.com',
#  'bashirian.biz',
#  'buckridge.link',
#  'clickfrog.ru',
#  'franecki.net',
#  'quitzon.net',
#  'reichelcormier.bid',
#  'wisokykulas.bid',
#  'conversiondashboard.com',
#  'clickinc.com',
#  'clicksor.com',
#  'clicksor.net',
#  'clicktripz.com',
#  'clickwinks.com',
#  'clicmanager.fr',
#  'clixtell.com',
#  'cloud-media.fr',
#  'clovenetwork.com',
#  'cmads.com.tw',
#  'cmadsasia.com',
#  'cmadseu.com',
#  'cmmeglobal.com',
#  'cognitivematch.com',
#  'collective-media.net',
#  'collective.com',
#  'oggifinogi.com',
#  'tumri.com',
#  'tumri.net',
#  'yt1187.net',
#  'apmebf.com',
#  'awltovhc.com',
#  'cj.com',
#  'ftjcfx.com',
#  'kcdwa.com',
#  'qksz.com',
#  'qksz.net',
#  'tqlkg.com',
#  'yceml.net',
#  'communicatorcorp.com',
#  'compasslabs.com',
#  'complex.com',
#  'complexmedianetwork.com',
#  'adxpose.com',
#  'proxilinks.com',
#  'proximic.com',
#  'proximic.net',
#  'connatix.com',
#  'pricegrabber.com',
#  'consiliummedia.com',
#  'consumable.com',
#  'adrolays.com',
#  'adrolays.de',
#  'df-srv.de',
#  'contaxe.com',
#  'contentabc.com',
#  'admailtiser.com',
#  'contextin.com',
#  'agencytradingdesk.net',
#  'contextuads.com',
#  'contextweb.com',
#  'convergedirect.com',
#  'convergetrack.com',
#  'adserver.com',
#  'conversantmedia.com',
#  'dotomi.com',
#  'dtmpub.com',
#  'emjcd.com',
#  'fastclick.com',
#  'fastclick.net',
#  'greystripe.com',
#  'lduhtrp.net',
#  'mediaplex.com',
#  'valueclick.com',
#  'valueclick.net',
#  'valueclickmedia.com',
#  'conversionruler.com',
#  'conversive.nl',
#  'coremotives.com',
#  'adify.com',
#  'afy11.net',
#  'coxdigitalsolutions.com',
#  'cpmstar.com',
#  'adreadypixels.com',
#  'cpxadroit.com',
#  'cpxinteractive.com',
#  'creafi.com',
#  'crimtan.com',
#  'crispmedia.com',
#  'criteo.com',
#  'criteo.net',
#  'hlserve.com',
#  'hooklogic.com',
#  'storetail.io',
#  'crosspixel.net',
#  'crosspixelmedia.com',
#  'crsspxl.com',
#  'curalate.com',
#  'cxense.com',
#  'emediate.biz',
#  'emediate.com',
#  'emediate.dk',
#  'emediate.eu',
#  'cyberplex.com',
#  'dada.pro',
#  'simply.com',
#  'nexac.com',
#  'nextaction.net',
#  'datamind.ru',
#  'dataxu.com',
#  'dataxu.net',
#  'mexad.com',
#  'w55c.net',
#  'aroa.io',
#  'datonics.com',
#  'pro-market.net',
#  'datranmedia.com',
#  'displaymarketplace.com',
#  'datvantage.com',
#  'dc-storm.com',
#  'stormiq.com',
#  'dedicatedmedia.com',
#  'dedicatednetworks.com',
#  'delivr.com',
#  'percentmobile.com',
#  'adaction.se',
#  'de17a.com',
#  'deltaprojects.se',
#  'demandmedia.com',
#  'indieclick.com',
#  'adcloud.com',
#  'adcloud.net',
#  'dp-dhl.com',
#  'developermedia.com',
#  'lqcdn.com',
#  'dgit.com',
#  'eyeblaster.com',
#  'eyewonder.com',
#  'mdadx.com',
#  'serving-sys.com',
#  'unicast.com',
#  'dianomi.com',
#  'did-it.com',
#  'didit.com',
#  'impact-ad.jp',
#  'adready.com',
#  'adreadytractions.com',
#  'digitalriver.com',
#  'keywordmax.com',
#  'netflame.cc',
#  'digitaltarget.ru',
#  'digitize.ie',
#  'directadvert.ru',
#  'directresponsegroup.com',
#  'ppctracking.net',
#  'directtrack.com',
#  'disqusads.com',
#  'districtm.io',
#  'dmpxs.com',
#  'doublepimp.com',
#  'bid-tag.com',
#  'doublepositive.com',
#  'adsymptotic.com',
#  'drawbrid.ge',
#  'ds-iq.com',
#  'dsnrgroup.com',
#  'dsnrmg.com',
#  'traffiliate.com',
#  'z5x.com',
#  'z5x.net',
#  'dynadmic.com',
#  'dyntrk.com',
#  'dynamicoxygen.com',
#  'exitjunction.com',
#  'px-eu.dynamicyield.com',
#  'px.dynamicyield.com',
#  'earnify.com',
#  'ebay.com',
#  'ebayimg.com',
#  'ebaystatic.com',
#  'effectivemeasure.com',
#  'effectivemeasure.net',
#  'e-kolay.net',
#  'ekolay.net',
#  'eleavers.com',
#  'usemax.de',
#  'emerse.com',
#  'brealtime.com',
#  'clearstream.tv',
#  'emxdgt.com',
#  'emxdigital.com',
#  'enecto.com',
#  'bnmla.com',
#  'engagebdr.com',
#  'appmetrx.com',
#  'engago.com',
#  'enginenetwork.com',
#  'ensighten.com',
#  'entireweb.com',
#  'epicadvertising.com',
#  'epicmarketplace.com',
#  'epicmobileads.com',
#  'theepicmediagroup.com',
#  'trafficmp.com',
#  'epsilon.com',
#  'eqads.com',
#  'ero-advertising.com',
#  'eskimi.com',
#  'etarget.eu',
#  'etargetnet.com',
#  'adwitserver.com',
#  'etineria.com',
#  'etrigue.com',
#  'mybuys.com',
#  'veruta.com',
#  'everydayhealth.com',
#  'waterfrontmedia.com',
#  'engineseeker.com',
#  'evisionsmarketing.com',
#  'evolvemediacorp.com',
#  'evolvemediametrics.com',
#  'gorillanation.com',
#  'ewaydirect.com',
#  'ixs1.net',
#  '777seo.com',
#  'ewebse.com',
#  'excitad.com',
#  'exelate.com',
#  'exelator.com',
#  'exoclick.com',
#  'exosrv.com',
#  'audienceiq.com',
#  'experian.com',
#  'expo-max.com',
#  'extensionfactory.com',
#  'extensions.ru',
#  'eyeconomy.co.uk',
#  'eyeconomy.com',
#  'sublimemedia.net',
#  'eyenewton.ru',
#  'eyereturn.com',
#  'eyereturnmarketing.com',
#  'eyeviewdigital.com',
#  'adsfac.eu',
#  'adsfac.info',
#  'adsfac.net',
#  'adsfac.sg',
#  'adsfac.us',
#  'facilitatedigital.com',
#  'fairfax.com.au',
#  'fxj.com.au',
#  'faithadnet.com',
#  'fanplayr.com',
#  'fathomdelivers.com',
#  'fathomseo.com',
#  'federatedmedia.net',
#  'fmpub.net',
#  'lijit.com',
#  'fetchback.com',
#  'fiksu.com',
#  'financialcontent.com',
#  'fizzbuzzmedia.com',
#  'fizzbuzzmedia.net',
#  'flashtalking.com',
#  'flite.com',
#  'widgetserver.com',
#  'flocktory.com',
#  'adingo.jp',
#  'fluct.jp',
#  'flytxt.com',
#  'brandsideplatform.com',
#  'forbes.com',
#  'fimserve.com',
#  'foxnetworks.com',
#  'foxonestop.com',
#  'mobsmith.com',
#  'myads.com',
#  'othersonline.com',
#  'fout.jp',
#  'freedom.com',
#  'stickyadstv.com',
#  'adultfriendfinder.com',
#  'ffn.com',
#  'pop6.com',
#  'tracking.friends2follow.com',
#  'double-check.com',
#  'frogsex.com',
#  'fuel451.com',
#  'fuelx.com',
#  'futureads.com',
#  'resultlinks.com',
#  'servebom.com',
#  'fyber.com',
#  'game-advertising-online.com',
#  'games2win.com',
#  'inviziads.com',
#  'gamned.com',
#  'gannett.com',
#  'pointroll.com',
#  'gb-world.net',
#  'gemius.com',
#  'gemius.pl',
#  'genesismedia.com',
#  'genesismediaus.com',
#  'geniee.co.jp',
#  'gssprt.jp',
#  'geniegroupltd.co.uk',
#  'geoads.com',
#  'getglue.com',
#  'smrtlnks.com',
#  'adhigh.net',
#  'getintent.com',
#  'gismads.jp',
#  'glam.com',
#  'glammedia.com',
#  'fraudjs.io',
#  'gleam.io',
#  'globe7.com',
#  'gmossp-sp.jp',
#  'reemo-ad.jp',
#  'gnezdo.ru',
#  'godatafeed.com',
#  'goldbach.com',
#  'goldbachgroup.com',
#  'goldspotmedia.com',
#  'grapeshot.co.uk',
#  'crm4d.com',
#  'groceryshopping.net',
#  'groovinads.com',
#  'guj.de',
#  'ligatus.com',
#  'gumgum.com',
#  'gunggo.com',
#  'hands.com.br',
#  'harrenmedia.com',
#  'harrenmedianetwork.com',
#  'adacado.com',
#  'healthpricer.com',
#  'hearst.com',
#  'ic-live.com',
#  'iclive.com',
#  'icrossing.com',
#  'sptag.com',
#  'sptag1.com',
#  'sptag2.com',
#  'sptag3.com',
#  'hilltopads.com',
#  'hilltopads.net',
#  'shoporielder.pro',
#  'comclick.com',
#  'hi-media.com',
#  'horyzon-media.com',
#  'hotmart.com',
#  'hotwords.com',
#  'hotwords.es',
#  'hp.com',
#  'optimost.com',
#  'httpool.com',
#  'huntmads.com',
#  'hurra.com',
#  'digitru.st',
#  'iac.com',
#  'iacadvertising.com',
#  'i-behavior.com',
#  'ib-ibi.com',
#  'unica.com',
#  'id5-sync.com',
#  'idg.com',
#  'idgtechnetwork.com',
#  'ie8eamus.com',
#  '600z.com',
#  'ientry.com',
#  'ignitad.com',
#  'ignitionone.com',
#  'ignitionone.net',
#  'searchignite.com',
#  '360yield.com',
#  'improvedigital.com',
#  'anadcoads.com',
#  'inadco.com',
#  'inadcoads.com',
#  'indexexchange.com',
#  'impressiondesk.com',
#  'infectiousmedia.com',
#  'inflectionpointmedia.com',
#  'infogroup.com',
#  'infolinks.com',
#  'infra-ad.com',
#  'aerserv.com',
#  'inmobi.com',
#  'sproutinc.com',
#  'inner-active.com',
#  'innity.com',
#  'insightexpress.com',
#  'insightexpressai.com',
#  'inskinmedia.com',
#  'instinctive.io',
#  'instinctiveads.com',
#  'adsafemedia.com',
#  'adsafeprotected.com',
#  'iasds01.com',
#  'integralads.com',
#  'intentmedia.com',
#  'intentmedia.net',
#  'intergi.com',
#  'intermarkets.net',
#  'intermundomedia.com',
#  'ibpxl.com',
#  'internetbrands.com',
#  'interpolls.com',
#  'im-apps.net',
#  'inuvo.com',
#  'investingchannel.com',
#  'fg8dgt.com',
#  'iponweb.com',
#  'iponweb.net',
#  'centraliprom.com',
#  'iprom.net',
#  'iprom.si',
#  'mediaiprom.com',
#  'ipromote.com',
#  'clickmanage.com',
#  'iprospect.com',
#  'fengkongcloud.com',
#  'adversalservers.com',
#  'digbro.com',
#  'ismatlab.com',
#  'i.ua',
#  'jaroop.com',
#  'jasperlabs.com',
#  'tradelab.fr',
#  'jemmgroup.com',
#  'jink.de',
#  'jinkads.com',
#  'adcolony.com',
#  'jirbo.com',
#  'jivox.com',
#  'jobthread.com',
#  'juicyads.com',
#  'jumptap.com',
#  'justpremium.com',
#  'justuno.com',
#  'kargo.com',
#  'kenshoo.com',
#  'xg4ken.com',
#  'keyade.com',
#  'keywee.co',
#  'kissmyads.com',
#  '103092804.com',
#  'kitaramedia.com',
#  'keewurd.com',
#  'kitd.com',
#  'peerset.com',
#  'kitewheel.com',
#  'admost.com',
#  'kokteyl.com',
#  'komli.com',
#  'kontera.com',
#  'adsummos.com',
#  'adsummos.net',
#  'korrelate.com',
#  'ibsys.com',
#  'lakana.com',
#  'layer-ad.org',
#  'layer-ads.net',
#  'leadbolt.com',
#  'leadforce1.com',
#  'leadformix.com',
#  'leanplum.com',
#  'legolas-media.com',
#  'levexis.com',
#  'adbull.com',
#  'lexosmedia.com',
#  'lfstmedia.com',
#  'lifestreetmedia.com',
#  'linkconnector.com',
#  'linkz.net',
#  'listrak.com',
#  'listrakbi.com',
#  'liadm.com',
#  'liveintent.com',
#  'liveinternet.ru',
#  'yadro.ru',
#  'liveramp.com',
#  'tvpixel.com',
#  'lkqd.com',
#  'lkqd.net',
#  'localyokelmedia.com',
#  'localytics.com',
#  'lockerdome.com',
#  'longboardmedia.com',
#  'loomia.com',
#  'lfov.net',
#  'loopfuse.net',
#  'loopme.com',
#  'lotlinx.com',
#  'lowermybills.com',
#  'lptracker.io',
#  'lucidmedia.com',
#  'm6d.com',
#  'media6degrees.com',
#  'madhouse.cn',
#  'dinclinx.com',
#  'madisonlogic.com',
#  'madvertise.com',
#  'domdex.com',
#  'domdex.net',
#  'magnetic.com',
#  'qjex.net',
#  'dialogmgr.com',
#  'magnify360.com',
#  'campaign-archive1.com',
#  'list-manage.com',
#  'mailchimp.com',
#  'bannerbank.ru',
#  'manifest.ru',
#  'industrybrains.com',
#  'marchex.com',
#  'marimedia.net',
#  'dt00.net',
#  'dt07.net',
#  'marketgid.com',
#  'marketo.com',
#  'marketo.net',
#  'martiniadnetwork.com',
#  'martinimedianetwork.com',
#  'mashero.com',
#  'chemistry.com',
#  'match.com',
#  'meetic-partners.com',
#  'adnetinteractive.com',
#  'adsmarket.com',
#  'matomy.com',
#  'matomymarket.com',
#  'matomymedia.com',
#  'mediawhiz.com',
#  'optimatic.com',
#  'xtendmedia.com',
#  'maxbounty.com',
#  'mb01.com',
#  'maxpointinteractive.com',
#  'maxusglobal.com',
#  'mxptint.net',
#  'mdotm.com',
#  'mediabrix.com',
#  'mediacom.com',
#  ...]

# %%
for fqdn, details in dict_fqdns.items():
    if fqdn in tracking or fqdn in advertising:
        details['ATSes'] = "ATSes"
        print(fqdn)
    else:
        details['ATSes'] = "others"
# Out:
# fireoscaptiveportal.com

# %% [markdown]
# ## 8. Find Parties

# %%
for fqdn, details in dict_fqdns.items():
    try:
        if details['organization'] == 'Amazon Technologies, Inc.':
            details['Party'] = "Platform-based"
            continue
        if details['organization'] == 'Sirius XM Holdings Inc.':
            details['Party'] = "First-Party"
            continue
        else:
            details['Party'] = "Third-Party"
    except:
        print(fqdn)

# %%
dict_fqdns
# Out:
# {'fireoscaptiveportal.com': {'domain_name': 'fireoscaptiveportal.com',
#   'SLD': 'fireoscaptiveportal',
#   'subdomain': '',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'acsechocaptiveportal.com': {'domain_name': 'acsechocaptiveportal.com',
#   'SLD': 'acsechocaptiveportal',
#   'subdomain': '',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'todo-ta-g7g.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'todo-ta-g7g',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'ntp-g7g.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'ntp-g7g',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'api.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'api',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'd1gsg05rq1vjdw.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'd1gsg05rq1vjdw',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'dss-na.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'dss-na',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'ffs-provisioner-config.amazon-dss.com': {'domain_name': 'amazon-dss.com',
#   'SLD': 'amazon-dss',
#   'subdomain': 'ffs-provisioner-config',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'dcape-na.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'dcape-na',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'd3p8zr0ffa9t17.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'd3p8zr0ffa9t17',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'www.google.com': {'domain_name': 'google.com',
#   'SLD': 'google',
#   'subdomain': 'www',
#   'organization': 'Google LLC',
#   'ATSes': '',
#   'Party': 'Third-Party'},
#  'connectivitycheck.gstatic.com': {'domain_name': 'gstatic.com',
#   'SLD': 'gstatic',
#   'subdomain': 'connectivitycheck',
#   'organization': 'Google LLC',
#   'ATSes': '',
#   'Party': 'Third-Party'},
#  'time.android.com': {'domain_name': 'android.com',
#   'SLD': 'android',
#   'subdomain': 'time',
#   'organization': 'Google LLC',
#   'ATSes': '',
#   'Party': 'Third-Party'},
#  'mobile-gtalk.l.google.com': {'domain_name': 'google.com',
#   'SLD': 'google',
#   'subdomain': 'mobile-gtalk.l',
#   'organization': 'Google LLC',
#   'ATSes': '',
#   'Party': 'Third-Party'},
#  'bob-dispatch-prod-na.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'bob-dispatch-prod-na',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  's3-w.us-east-1.amazonaws.com': {'domain_name': 'amazonaws.com',
#   'SLD': 'amazonaws',
#   'subdomain': 's3-w.us-east-1',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'prod.amcs-tachyon.com': {'domain_name': 'amcs-tachyon.com',
#   'SLD': 'amcs-tachyon',
#   'subdomain': 'prod',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'msh.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'msh',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'cluster-web.meethue.com': {'domain_name': 'meethue.com',
#   'SLD': 'meethue',
#   'subdomain': 'cluster-web',
#   'organization': 'Philips International B.V.',
#   'ATSes': '',
#   'Party': 'Third-Party'},
#  'ingestion.us-east-1.prod.arteries.alexa.a2z.com': {'domain_name': 'a2z.com',
#   'SLD': 'a2z',
#   'subdomain': 'ingestion.us-east-1.prod.arteries.alexa',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'dxz5jxhrrzigf.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'dxz5jxhrrzigf',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'mediaserver-sv5-t1-1-v4v6.pandora.com': {'domain_name': 'pandora.com',
#   'SLD': 'pandora',
#   'subdomain': 'mediaserver-sv5-t1-1-v4v6',
#   'organization': 'Sirius XM Holdings Inc.',
#   'ATSes': '',
#   'Party': 'First-Party'},
#  't1-5.p-cdn.us': {'domain_name': 'p-cdn.us',
#   'SLD': 'p-cdn',
#   'subdomain': 't1-5',
#   'organization': 'Sirius XM Holdings Inc.',
#   'ATSes': '',
#   'Party': 'First-Party'},
#  'mlis.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'mlis',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'd2of0gfv69hsgh.cloudfront.net': {'domain_name': 'cloudfront.net',
#   'SLD': 'cloudfront',
#   'subdomain': 'd2of0gfv69hsgh',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'},
#  'updates.amazon.com': {'domain_name': 'amazon.com',
#   'SLD': 'amazon',
#   'subdomain': 'updates',
#   'organization': 'Amazon Technologies, Inc.',
#   'ATSes': '',
#   'Party': 'Platform-based'}}

# %% [markdown]
# ## 9. Edit Final DataFrame

# %%
main_df = {'fqdn': [], 'domain_name': [], 'SLD': [], 'subdomain' : [] ,'organization': [], 'ATSes': [], 'Party': []}


for i in range(len(network_json)):
    if 'ip' in network_json[i]["_source"]["layers"].keys():
        ip_dst =   network_json[i]["_source"]["layers"]['ip']['ip.dst']
        if not ip_dst.startswith("10.42.") and not ip_dst.startswith("255.255.") and not ip_dst.startswith("8.8.") and not ip_dst.startswith("0.0.") and not ip_dst.startswith("224.0") and not ip_dst.startswith("239.255"):
            fqdn = dns_resolutions[ip_dst]
            main_df['fqdn'].append(fqdn)
            main_df['domain_name'].append(dict_fqdns[fqdn]['domain_name'])
            main_df['subdomain'].append(dict_fqdns[fqdn]['subdomain'])         
            main_df['SLD'].append(dict_fqdns[fqdn]['SLD'])
            main_df['organization'].append(dict_fqdns[fqdn]['organization'])
            main_df['ATSes'].append(dict_fqdns[fqdn]['ATSes'])
            main_df['Party'].append(dict_fqdns[fqdn]['Party'])

# %%
df = pd.DataFrame.from_dict(main_df)
df.to_csv(os.path.join(base_out,"report.csv"), sep=',')
df
# Out:
#                                         fqdn               domain_name  \
# 0                    fireoscaptiveportal.com   fireoscaptiveportal.com
# 1                   acsechocaptiveportal.com  acsechocaptiveportal.com
# 2                    fireoscaptiveportal.com   fireoscaptiveportal.com
# 3                    fireoscaptiveportal.com   fireoscaptiveportal.com
# 4                     todo-ta-g7g.amazon.com                amazon.com
# ...                                      ...                       ...
# 18840          d1gsg05rq1vjdw.cloudfront.net            cloudfront.net
# 18841          d1gsg05rq1vjdw.cloudfront.net            cloudfront.net
# 18842  mediaserver-sv5-t1-1-v4v6.pandora.com               pandora.com
# 18843  mediaserver-sv5-t1-1-v4v6.pandora.com               pandora.com
# 18844        bob-dispatch-prod-na.amazon.com                amazon.com
#
#                         SLD                  subdomain  \
# 0       fireoscaptiveportal
# 1      acsechocaptiveportal
# 2       fireoscaptiveportal
# 3       fireoscaptiveportal
# 4                    amazon                todo-ta-g7g
# ...                     ...                        ...
# 18840            cloudfront             d1gsg05rq1vjdw
# 18841            cloudfront             d1gsg05rq1vjdw
# 18842               pandora  mediaserver-sv5-t1-1-v4v6
# 18843               pandora  mediaserver-sv5-t1-1-v4v6
# 18844                amazon       bob-dispatch-prod-na
#
#                     organization   ATSes           Party
# 0      Amazon Technologies, Inc.   ATSes  Platform-based
# 1      Amazon Technologies, Inc.  others  Platform-based
# 2      Amazon Technologies, Inc.   ATSes  Platform-based
# 3      Amazon Technologies, Inc.   ATSes  Platform-based
# 4      Amazon Technologies, Inc.  others  Platform-based
# ...                          ...     ...             ...
# 18840  Amazon Technologies, Inc.  others  Platform-based
# 18841  Amazon Technologies, Inc.  others  Platform-based
# 18842    Sirius XM Holdings Inc.  others     First-Party
# 18843    Sirius XM Holdings Inc.  others     First-Party
# 18844  Amazon Technologies, Inc.  others  Platform-based
#
# [18845 rows x 7 columns]

# %% [markdown]
# # Visualization

# %% [markdown]
# ### 1. Plot Taxonomy

# %%
other = [1501, 3778, 49]

ATSes = [7, 0, 0]

index = ['Platform-based', 'First-Party', 'Third-Party']

df_taxonomy = pd.DataFrame({'others': other, 'ATSes': ATSes}, index=index)

ax = df_taxonomy.plot.bar(stacked=True, color={"others": "#022851", "ATSes": "#FFBF00"})

# %% [markdown]
# ### 2. Platfom-based FQDNs

# %%
df_fqdn = df.loc[df['Party'] == 'Platform-based', 'fqdn']
platform_base = {}
for fqdn in df_fqdn:
    if fqdn not in platform_base:
        platform_base[fqdn] = 1
    else:
        platform_base[fqdn] += 1
fqdn_skill_num_sorted = dict(sorted(platform_base.items(), key=lambda kv: kv[1], reverse=True))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
fqdns = [fqdn for fqdn, skills_nums in fqdn_skill_num_sorted.items()]
y_pos = np.arange(0,len(fqdn_skill_num_sorted),1)
performance = [skills_nums for fqdn, skills_nums in fqdn_skill_num_sorted.items()]
#error = np.random.rand(len(fqdns))

ax.barh(y_pos, performance, align='edge', color = '#033266')
ax.set_yticks(y_pos)
ax.set_yticklabels(fqdns)
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('number of access')
ax.set_title('Paltform_based FQDNs accessed by skills')
plt.savefig('platform_barchart.png')
plt.show()

# %%
df_fqdn_non = df.loc[(df['Party'] == 'Third-Party') | (df['Party'] == 'First-Party'), 'fqdn']
non_platform_base = {}
for fqdn in df_fqdn_non:
    if fqdn not in non_platform_base:
        non_platform_base[fqdn] = 1
    else:
        non_platform_base[fqdn] += 1
fqdn_skill_num_sorted_non = dict(sorted(non_platform_base.items(), key=lambda kv: kv[1], reverse=True))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
fqdns = [fqdn for fqdn, skills_nums in fqdn_skill_num_sorted_non.items()]
y_pos = np.arange(0,len(fqdn_skill_num_sorted_non),1)
performance = [skills_nums for fqdn, skills_nums in fqdn_skill_num_sorted_non.items()]
#error = np.random.rand(len(fqdns))

ax.barh(y_pos, performance, align='edge', color='#FFBF00')
ax.set_yticks(y_pos)
ax.set_yticklabels(fqdns)
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('number of access')
ax.set_title('Top-30 domains accessed by skills')
plt.savefig('thirdparty_barchart.png')
plt.show()
