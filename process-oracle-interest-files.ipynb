# %%
# !pip install PyMuPDF
import fitz 
import utilities

# %%
DATA_DIR = '/media/umar/Data/work/voice-assistant-central/data/inferred-interests-week-later/'

# %%
def get_text_from_pdf(path):
    with fitz.open(path) as doc:
        text = ""
        for idx, page in enumerate(doc):
            if idx < 3:
                continue
            text += page.get_text()
    return text.split('\n')


def interests_per_persona(interest_files):
    interests = {}
    
    for interest_file in interest_files:
        raw_interests = get_text_from_pdf(interest_file)
        
        processed_content = set()
        for line in raw_interests:
            if line.strip() == 'Segment Detail View' or \
            line.strip().startswith('Generated: ') or \
            line.strip() == '':
                continue
            
#             if line.count('>') < 3:
#                 continue
            try:    
                processed_content.add(line.rsplit('>')[-2].strip() + ' > ' + line.rsplit('>')[-1].strip())
            except Exception:
                pass
            
        interests[interest_file.split('/')[-1].replace('.pdf','')] = processed_content
    
    return interests 


def get_common_inerests(interests):
    common_interests = set()
    
    for persona in interests:
        if len(common_interests) == 0:
            common_interests = set(interests[persona])
            
        common_interests = common_interests.intersection(interests[persona])
    
    return common_interests


def get_unique_interests(interests, common_interests):
    unique_interests = {}
    for persona in interests:
        
        if persona not in unique_interests:
            unique_interests[persona] = set()
        
        for interest in interests[persona]:
            if interest not in common_interests:
                unique_interests[persona].add(interest)
                
    return unique_interests


def get_exclusive_interests(interests):
    exclusive_interests = {}
    for persona in interests:
        
        if persona not in exclusive_interests:
            exclusive_interests[persona] = set(interests[persona])
        
        for other_persona in interests:
            if persona == other_persona:
                continue
                
            exclusive_interests[persona] -= set(interests[other_persona])
                
    return exclusive_interests

# %%
j = {1,2,3,4,5,6,7,8,9}
j -= {5,6,7,8}
j
# Out:
# {1, 2, 3, 4, 9}

# %%
interest_files = utilities.get_files_in_a_directory(DATA_DIR)

# %%
interests = interests_per_persona(interest_files)

# %%
common_interests = get_common_inerests(interests)

# %%
common_interests
# Out:
# {'AdAdvisor > Targus GET - 2831',
#  'Audiences by Oracle > Business (B2B)',
#  'Audiences by Oracle > Media and Entertainment',
#  'Audiences by Oracle > Retail',
#  'Audiences by Oracle > Technology and Computing',
#  'Audiences by Ziff Davis > PCMag',
#  'Audiences by Ziff Davis > Tech - B2B',
#  'BlueKai Internal - Private > Data Center',
#  'Brand > Apple',
#  'Brand > CyberLink',
#  'Brand > DELL',
#  'Brand > GOOGLE',
#  'Brand > MOTOROLA',
#  'Brand > Nokia',
#  'Brand > QUALCOMM',
#  'Brand > SONY',
#  'Brand > SYMANTEC',
#  'Branded Data > AcquireWeb - Claritas',
#  'Branded Data > Audiences by Ziff Davis',
#  'Browser > Firefox',
#  'Computers > Networking',
#  'Computers > Networking & Communication',
#  'Computers > Networking and Wireless',
#  'Data Center > Phoenix',
#  'Demographics > Age',
#  'Demographics > Gender',
#  'Device Type > Computers',
#  'Hardware > Computers',
#  'IP based > United States',
#  'In-Market > Brand',
#  'In-Market > Device Type',
#  'In-Market > Retail',
#  'Interest (Affinity) > Computers',
#  'Interest > Shopping',
#  'Interest > Technology and Computers',
#  'Interests > Technology - Consumer Electronics (CE)',
#  'Lotame > Lotame ID Swap Pixel - 5907',
#  'Media and Entertainment > Connected TV and Over-the-Top (CTV and OTT)',
#  'Mobile Plans & Broadband/ Internet Service Providers (ISP) > Broadband/Internet Service Providers (ISP)',
#  'Oracle BlueKai > Business (B2B)',
#  'Oracle BlueKai > In-Market',
#  'Oracle BlueKai > Interest',
#  'Overlap > Pool: 17724 (Centro DSP P2076)',
#  'Overlap > Pool: 2964 (DataXu  P173)',
#  'Overlap > Pool: 2981 (Google P623) - All',
#  'Overlap > Pool: 3085 (AppNexus P608)',
#  'Overlap > Pool: 35244(Beeswax P3931)',
#  'Overlap > Pool: 4413 (TubeMogul P920)',
#  'Overlap > Pool: 5386 (The Trade Desk P1090)',
#  'PCMag > Interests',
#  'Pool: 2981 (Google P623) - All > Pool: 2981 (Google P623) - Add',
#  'Retail > In-Market',
#  'Shopping > Coupon Shoppers',
#  'Signal Data > Source Categories',
#  'Sites > Tech - CE',
#  'Tech - B2B > Networking & Infrastructure',
#  'Tech - CE > PCMag.com',
#  'Tech - CE > speedtest.net',
#  'Technology - Consumer Electronics (CE) > Hardware',
#  'Technology - Consumer Electronics (CE) > Mobile Plans & Broadband/ Internet Service Providers (ISP)',
#  'Technology and Computers > Computers',
#  'Technology and Computing > Interest (Affinity)',
#  'Type > Computer',
#  'United States > Washington',
#  'User Type > Desktop Cookie',
#  'Washington > Seattle-Tacoma-Bellevue',
#  'Ziff Davis - ODC Seat - Private > In-Market',
#  'Ziff Davis - ODC Seat - Private > Sites'}

# %%
unique_interests = get_unique_interests(interests, common_interests)
exclusive_interests = get_exclusive_interests(interests)

# %%
exclusive_interests['Religion-Spirituality']
# Out:
# {'A/B Test Groups > Group 11',
#  'Age > 40 - 44',
#  'Arts & Entertainment > Movies',
#  'Arts & Entertainment > TV',
#  'Arts, Entertainment & Media > Broadcasting',
#  'Audio & Video > MP3 Players',
#  'Audio and Visual > Music Players',
#  'B2B > Industries & Occupations',
#  'Books & Magazines > Audio Books',
#  'Brand > KitchenAid',
#  'Brand > NBC',
#  'Brand > Netflix',
#  'Brand > PokÃ©mon',
#  'Brand > Samsung',
#  'Brand > Walmart',
#  'Cell Phones & Mobile Carriers > Samsung',
#  'Cell Phones and Plans > Accessories',
#  'Cell Phones and Plans > Devices',
#  'Cell Phones and Plans > Smartphones',
#  'Computers > Handheld',
#  'Custom Categories > Graduation Gift Buyers',
#  'Devices > Apple (iPhone)',
#  'Devices > Apple iPhone',
#  'Devices > Samsung',
#  'Electronics & Gadgets > Music Players',
#  'Electronics > Audio & Video',
#  'Electronics > Handhelds & Tablets',
#  'Estimated Discretionary Income Percent > 40 - 49%',
#  'Exercise & Fitness > Cardio Equipment',
#  'Exercise & Fitness > Jump Rope',
#  'Genres > Action',
#  'In-Market > Cell Phones & Mobile Carriers',
#  'In-Market > Electronics',
#  'In-Market > Exercise & Fitness',
#  'In-Market > Mobile Phones',
#  'In-Market > Shopping',
#  'In-Market > Tablets and e-Readers',
#  'Industries & Occupations > Arts, Entertainment & Media',
#  'Industry - Type of Business > 40 - 49 Transportation, Communications & Utilities',
#  'Industry - Type of Business > 84 - 86 Art & Membership Organizations',
#  'Interests > Exercise & Fitness',
#  'Interests > Lifestyles',
#  'Internet & Online Activities > Streaming Media & Downloads',
#  'Lifestyles > Social Activists',
#  'Mobile Phone Brands > Apple iPhone',
#  'Mobile Phone Brands > Samsung',
#  'Mobile Phone Type > Smartphones',
#  'Mobile Phones (Cell Phones) > Mobile Phone Accessories',
#  'Mobile Phones (Cell Phones) > iOS (iPhone)',
#  'Mobile Phones > Accessories',
#  'Mobile Phones > Devices',
#  'Movies > Documentaries',
#  'Networks > NBC',
#  'News > Blogs',
#  'Retail > Cell Phones and Plans',
#  'Seasonal > Black Friday',
#  'Shopping > Venue',
#  'Smartphones > iOS (iPhone)',
#  'Streaming Media & Downloads > Video',
#  'TV > Genres',
#  'TV > Networks',
#  'Transportation & Logistics > Logistics & Warehousing',
#  'Types > Smartphones',
#  'Venue > Discount & Big Box Stores',
#  'Venue > Online Shopping'}

# %%
exclusive_interests['Wine-Beverages']
# Out:
# {'Ability to Pay > Moderate Ability to Pay',
#  'Active - 24 Months > Home Improvement',
#  'Age > 18 - 24',
#  'Age > 55 - 59',
#  'Age Range > 65-74',
#  'Age of Children in Household > 13-18',
#  'All Categories Frequency > Number of Credit Purchases Last 24 Months: 11+',
#  'All Categories Frequency > Number of Credit Purchases Total: 16+',
#  'All Categories Frequency > Number of Purchases Last 13-18 Months: 5+',
#  'All Categories Frequency > Number of Purchases Last 4-6 Months: 5+',
#  'All Categories Frequency > Number of Purchases Total: 26+',
#  'All Categories Recency > Total Dollars Last 10-12 Months: Dollars Spent: $31 - $154',
#  'Alliant > CPG',
#  'Alliant > Education',
#  'Alliant > Family Interests',
#  'Apparel > Ashley Stewart Buyer Propensity',
#  'Apparel > Belk Buyer Propensity',
#  'Apparel > Brooks Brothers Buyer Propensity',
#  'Apparel > Crocs Buyer Propensity',
#  'Apparel > J.JILL Buyer Propensity',
#  'Apparel > Jordan Buyer Propensity',
#  'Apparel > Lord & Taylor Buyer Propensity',
#  'Apparel > New Balance Buyer Propensity',
#  'Automotive > Domestic Car Owners',
#  'Automotive Owners > Own a Chevrolet',
#  'Average Bank Card Balance Transfer Amount > $1-$2,499',
#  'Average Household Income > Less Than $20000',
#  'Back to School > College Students',
#  'Big Box Retail > Kmart Buyer Propensity',
#  'Brands > Ace Hardware',
#  "Brands > Campbell's Healthy Request",
#  'Brands > Healthy Choice',
#  'Brands > Pet Supplies',
#  'Buyers > Costume Jewelry',
#  'Buyers > Frequent Offline Shoppers (November/December)',
#  'Buyers > Frequent Online Shoppers (November/December)',
#  'Buyers > Full-Figured Merchandise',
#  'Buyers > Indoor Home Decor Products',
#  'Buyers > Merchandise & Sweepstakes',
#  'COVID > Delivery/Pickup - Amazon Shoppers',
#  'CPG > Crest Buyer Propensity',
#  'CPG > Fancy Feast',
#  'CPG > Friskies',
#  'CPG > Frito - Lay snacks',
#  'CPG > Household Goods',
#  'CPG > Kraft Buyer Propensity',
#  'Casual Wear > Handbags, Wallets & Cases',
#  'Charities and Non-Profits > Health',
#  'Chevy > ODC Experian Chevrolet In Market RTN Trailblazer 2021',
#  'Children Apparel > Dollars Spent: Budget Spender',
#  'Children Apparel > Power Spender',
#  'Children Merchandise > Dollars Spent: Budget Spender',
#  'Children in Household > Child Near High School Graduation',
#  'Children in Household > Teen Driver',
#  'Clorox > Pine-Sol',
#  'Company Employees > Micro (5 - 10)',
#  'Company Sales > Small ($500K - $1M)',
#  'Company Tenure > 16 Years or Greater',
#  'Composite Segments (Audience Clusters) > Active Hobbyists',
#  'Composite Segments (Audience Clusters) > Cosmetic & Beauty Lovers',
#  'Composite Segments (Audience Clusters) > Digital Purchasing Parents',
#  'Composite Segments (Audience Clusters) > Home Improvement Masters',
#  'Composite Segments (Audience Clusters) > Literature & Music Lovers',
#  'Composite Segments (Audience Clusters) > Personal Care Multi-Buyers',
#  'Composite Segments (Audience Clusters) > Purchasing Parents',
#  'Composite Segments (Audience Clusters) > Shopaholic Hotline',
#  'Computer & Electronics > Cameras',
#  'ConAgra > Healthy Choice',
#  'Construction > Construction - special trade contractors',
#  'ConsumerSpend Combined > $10,000-$24,999',
#  'ConsumerSpend Home Furnishings > $100-$499',
#  'Cooking and Specialty Oils > Olive Oils Purchasers',
#  'Credit Cards > Premium Card',
#  'Customer Modeled > Upscale',
#  'Decision Making Styles > Deal Seekers',
#  'Demographics > Household Income $50k+',
#  'Demographics > No Presence of Child',
#  'Dining > Greater than $7,500',
#  'Discretionary Spending > $20,000 - $29,999',
#  'Donations > Animal Welfare',
#  'Donations > Environment & Wildlife',
#  'Donations > Health',
#  'Donations > Veterans',
#  'Ecommerce > Amazon.com Buyer Propensity',
#  'Ecommerce > Ebay Buyer Propensity',
#  'Economic Cohorts > $50K-$100K Income, Age - Young (<35), Getting Ahead - Young City Families - E26',
#  'Economic Spectrum > Less Than $55K Income - Sparing Spenders',
#  'Education > Education/Teacher',
#  'Education and Career > Self-Improvement',
#  'Electronics > Norton Buyer Propensity',
#  'Electronics > P.C. Richard & Son Buyer Propensity',
#  'Elements > ElementOne Segment 157 - Up and Coming Suburban Older Home Owners Without Children',
#  'Employment > Open to Changing Jobs',
#  'Engagement Channels > Traditional Newspaper',
#  'Entertainment & Pastimes > Book Fanatics',
#  'Entertainment & Pastimes > Hobbyists & Collectors',
#  'Entertainment > Fox',
#  'Entertainment > NBC',
#  'Estimated Home Value (USD) > $200,000 - $299,000',
#  'Estimated Household Income (USD) > HHI: Less than $20,000',
#  'Estimated Household Income (USD) > Less than $20,000',
#  'Estimated Household Income > $150K-$199.9K',
#  'Estimated Household Investable Assets > $750,000 - $999,999',
#  'Estimated Net Worth (USD) > $50,000 - $99,999',
#  'Estimated Net Worth > $250,000 to $374,999',
#  'Estimated Net Worth > $5,000 - $9,999',
#  'Events/Shows > Magic Las Vegas',
#  'Exercise > Yoga & Pilates Enthusiast',
#  'Family Interests > Apparel Product Buyers',
#  "Family Interests > Children's Products",
#  'Fashion and Accessories > Plus Size',
#  'Finance, Insurance, Real Estate > Real Estate',
#  'Financial > PayPal Buyer Propensity',
#  'Financial > Western Union Buyer Propensity',
#  'Financial Attributes > Donations',
#  'Financial Mobility > Future Income Range $50,000 - $99,999',
#  'Financially in Charge > Big Spenders',
#  'Food & Beverages > Healthy Choice',
#  'Food & Drugstore > Whole Foods Market Buyer Propensity',
#  'Ford > Mustang',
#  'Generations > Female Baby Boomers',
#  'Genres > DIY',
#  'Grocery > Frozen Dinner',
#  'Group L: Blue Sky Boomers > L42 - Rooted Flower Power',
#  'Health / Beauty & Cosmetics > Heartland Dental Buyer Propensity',
#  'Health / Beauty & Cosmetics > The Honest Company Buyer Propensity',
#  'Health Insurance > Humana',
#  'Health Insurance > Humana Insured',
#  'Health Supplements > Probiotic',
#  'Health and Well Being > Invincibles',
#  'Health and Wellness > Allergy and Sinus Care Purchasers',
#  'Health and Wellness > Ear, Nose and Eye Care Purchasers',
#  'Hobbies & Interests > Jewelry Making',
#  'Home & Family > Pet Owner',
#  'Home & Garden Interests > Arts & Crafts',
#  'Home & Household Goods > BrylaneHome Buyer Propensity',
#  'Home & Household Goods > Cuisinart Buyer Propensity',
#  'Home & Household Goods > Dewalt Buyer Propensity',
#  'Home & Household Goods > GE Buyer Propensity',
#  'Home & Household Goods > Menard Buyer Propensity',
#  'Home & Household Goods > Yankee Candle Buyer Propensity',
#  'Home > Lighting',
#  'Home > Mattress Pad',
#  'Home Goods: Furniture > Dollars Spent: Budget Spender',
#  'Home Goods: Furniture > Power Spender',
#  'Home Goods: Kitchen > Dollars Spent: Budget Spender',
#  'Home Market Value > $125,000 - $149,999',
#  'Home Value Range > $100 - $150k',
#  'Household Income > $150,000 - $199,999',
#  'Household Income > $35,000-$39,999',
#  'Household Income > HHI: $50,000-$59,999',
#  'Household Income Range > $1,000-$14,999',
#  'Household Income Range > $15,000-$19,999',
#  'In Market - Lease > Non Luxury Lease',
#  'In Market > Kroger Shoppers',
#  'In Market > Online Streaming Shoppers',
#  'In Market > Pet Insurance',
#  'Income 360 > Income Range $50,000 - $59,999',
#  'Income 360 > Total Income $50,000 - $59,999',
#  'Income > $40,000-$44,999',
#  'Income > $50,000-$54,999',
#  'Income > $50,000-$59,999',
#  'Industry > Finance',
#  'Industry > Finance, Insurance, Real Estate',
#  'Industry > Insurance',
#  'Insurance > Account Holders',
#  'Intenders > Cosmetics',
#  'Intenders > Costume Jewelry as a Gift',
#  'Intenders > Insurance Products',
#  'Intenders > Outdoor Related Products',
#  'Intenders > Plus Size Female Apparel',
#  'Intenders > Sign Up for a Contest',
#  'Intenders > Sign Up for a Travel Sweepstakes',
#  'Intenders > Small Appliances',
#  'Intenders > Sports Equipment & Apparel',
#  'Intenders > Sweepstakes Products',
#  'Interest > Self Improvement',
#  'Interests > Bird watching',
#  'Interests > Charity',
#  'Interests > Dieting',
#  'Interests > Fitness',
#  'Interests > Food Culinary Wine',
#  'Interests > Green Living',
#  'Interests > Knitting / Quilting / Sewing',
#  'Jewelry > Jewelry Cleaning & Care',
#  'Jewelry > Watch',
#  'Jewelry/Accessories > Dollars Spent:Mid-Level Spender',
#  'Job Role > Corporate Secretary',
#  'KIA > KIA Sportage',
#  'Kids Products > Fisher-Price Buyer Propensity',
#  'Kids Products > Gerber Buyer Propensity',
#  'Length of Residence (Months) > 120 to 149 months',
#  'Length of Residence > 20-24 Years',
#  'Length of Residence > Years: 20-24',
#  'Lifestyles > Self-Improvement',
#  'Likely Device or Viewing Method > Likely to View TV content on a Mobile Phone',
#  'Likely Donors > Health Causes',
#  'Likely Donors > LGBTQ Cause Donors',
#  'Likely TV Provider > On-Demand Streaming Service Subscribers',
#  'Make > Ford',
#  'Makes > Mitsubishi',
#  'Makes and Models > Mitsubishi',
#  'Mars > Pedigree',
#  'Max Scale > $50,000-$59,999',
#  'Median Home Value > $200,000-$299,999',
#  'Medical Utilization > Telemedicine',
#  "Men's Casual Apparel > Dollars Spent: Budget Spender",
#  'Mosaic > Group L: Blue Sky Boomers',
#  'Movies > Toy Story',
#  'Multibuyer Behaviors > Shopaholics',
#  'Music > Music Buyer Enthusiast',
#  'NFL > Miami Dolphins',
#  'NFL > Minnesota Vikings',
#  'NFL > New Orlean Saints',
#  'NFL > Pittsburgh Steelers',
#  'Narrow Age Range > 20-24',
#  'Net Worth > $750K - $999.9K',
#  'Net Worth > Less than $25,000',
#  'No Presence of Child > Age: 0-18',
#  'Occupation > Homemaker',
#  'Occupation > Retired',
#  'Own a Ford > Own a Ford Truck',
#  'Ownership Status > Rents Primary Residence',
#  'Pay Method > Discover Card',
#  'Pay Method > Mastercard',
#  'Pay Method > Pay by Instore House Charge',
#  'Pay Method > Visa',
#  'Persona > Religious Devotion',
#  'Personas > Big Chain Shoppers',
#  'Personas for Health > Learning the System - Engraved Invitation',
#  'Pet Owner > Dog',
#  'Pet Owner > Dog Owner',
#  'Pet Supplies > Pedigree',
#  'Pets > Pet Owner',
#  'Pets > Purina Buyer Propensity',
#  'Pets > Symphony IRI: Heavy Cat Food Buyers',
#  'Pets > Wet Cat Food',
#  'Products & Services Propensities > NASCAR Fans - Propensity',
#  'Purchase Behaviors > Mail Order Responder',
#  'Quick Service Restaurants (QSRs) > Taco Bell',
#  'Reading > Health Remedies',
#  'Reading > Medical Health',
#  'Reading > Religious Magazines',
#  'Regulation B (Reg B) Friendly Audiences > Insurance',
#  'Response Performance > Online Content Subscribers',
#  'Restaurants & Dining > Waitr Buyer Propensity',
#  'Retail Transactions > Children Apparel',
#  'Retail Transactions > Home Goods: Furniture',
#  'Retail Transactions > Sports Active Outdoors',
#  "Retail Transactions > Women's Plus-Size Apparel",
#  "Retail Transactions > Women's Upscale Apparel",
#  'Seasonal Audiences > Tax Season',
#  'Shoppers All Channels > Apparel',
#  'Shoppers All Channels > Outdoor Hard Goods',
#  'Shopping > Auctions',
#  'Shopping > Shopaholics',
#  'Sleep > Poor Sleep Quality',
#  'Sleepwear > Nightgown',
#  'Sleepwear > Robe',
#  'Social Networks > Super Passionate Influencers',
#  'Sports Active Outdoors > Dollars Spent: Mid-Level Spender',
#  'Sports Active Outdoors > Power Spender',
#  'Staggered Age Range > 18-24',
#  'State > KS',
#  'TV Dayparts > Likely Late Night Viewers',
#  'Telecom & Service Providers > Charter Buyer Propensity',
#  'Television > TV How-to Shows',
#  'Travel > Planning to Stay At Airbnb',
#  'Travel Preference > All Suite Hotel',
#  'Vehicle Make > In Market for a Kia',
#  'Vehicle Make > In Market for a Lincoln',
#  'Vehicle Make > In Market for a Mazda',
#  'Vehicle Make > In Market for a Mitsubishi',
#  'Vehicle Make > In Market for a Nissan',
#  'Vehicle Make > In Market for a Smart Car',
#  'Vehicle Type > In Market for a Family Vehicle',
#  'Video Games > Big Fish Games',
#  'Video Games > Candy Crush',
#  'Video Games > FIFA',
#  'Video Games > Fallout',
#  'Video Games > Final Fantasy',
#  'Video Games > Fortnite',
#  'Video Games > Legend of Zelda',
#  'Video Games > Madden',
#  'Video Games > Minecraft',
#  'Video Games > Mobile Games',
#  'Video Games > NBA 2K',
#  'Video Games > Ninja Celebrity',
#  'Video Games > Nintendo Switch',
#  'Video Games > PS4',
#  'Video Games > Role Playing Games',
#  'Video Games > Twitch com',
#  'Video Games > Xbox One',
#  'WealthComplete Deposits > Deposit Range $10,000 - $24,999',
#  'WealthCompleteÂ® HD Total Investable Assets > Asset Range $25,000 - $49,999',
#  "Women's > Women's Plus Size",
#  "Women's Athletic Apparel > Dollars Spent: Mid-Level Spender",
#  "Women's Interests > Cosmetics/Beauty",
#  "Women's Interests > Jewelry/Accessories",
#  "Women's Mid-Price Apparel > Dollars Spent: Heavy Spender",
#  "Women's Mid-Price Apparel > Number of Purchases: 5+",
#  "Women's Plus-Size Apparel > Dollars Spent: Budget Spender",
#  "Women's Plus-Size Apparel > Power Spender",
#  "Women's Upscale Apparel > Dollars Spent: Budget Spender",
#  "Women's Upscale Apparel > Power Spender",
#  'Year > 2001'}

# %%
exclusive_interests['SmartHome']
# Out:
# {'Age > 65 - 69',
#  'Estimated Discretionary Income Percent > 30 - 39%',
#  'Estimated Household Investable Assets > $1MM +',
#  'Family Position > Female HOH',
#  'Genre > Thriller Movie Streamers',
#  'Net Worth > $1M+',
#  'United States > Gifts/holiday items',
#  'United States > Not For Profit',
#  'United States > Young Family'}

# %%
exclusive_interests['Health-Fitness']
# Out:
# {'35-44 > 35-39',
#  'AFS Products > Millenials - High',
#  'Ability to Pay > Millennials - High Ability to Pay',
#  'Active & Influential Social Media Users > Facebook Influencers',
#  'AdAdvisor by Neustar > Style & Fashion',
#  'Adstra (formerly ALC) > Consumer In-Market',
#  'Advanced Demographics > Spanish Speakers',
#  'Age > 0-2 Years',
#  'Age of Children in Household (Kids) > Parents of Toddlers (3-5)',
#  'Age of Children in Household (Kids) > Parents of Toddlers (Ages 3-5)',
#  'Age of Children in Household > 3-5',
#  'AmeriLINK Online Behavioral Data > Cosmetology & Beauty Professionals',
#  'AmeribaseDigital > OTT & CTV',
#  'AmeribaseDigital > Technology & Software Buyers By Brand',
#  'Apparel > Jewelry',
#  'Auto Insurance > Geico',
#  'Auto Parts/Auto Repair > Auto Zone',
#  'Auto Parts/Auto Repair > Jiffy Lube',
#  'Auto, Cars and Trucks > Parts, Service and Tires',
#  'Automotive > Auto Insurance',
#  'Automotive > Auto Parts/Auto Repair',
#  'Autos > Aftermarket',
#  'Back To School > Consumer with Pre-School Aged Kids',
#  'Banking Propensity Segments > Millennials - Mass Affluent',
#  'Banking Propensity Segments > Millennials - Young and On the Road to Wealth',
#  'Banking Propensity Segments > Young and On the Road to Wealth',
#  'Baseball > MLB',
#  'Body Styles > Motorcycles',
#  'Brand Segment > Hersheys',
#  'Brands > Food Lion',
#  'Brands > Johnsonville',
#  "Brands > Lowe's",
#  'Brands and Retailers > Jiffy Lube',
#  'Business Profession > Professional Tech Business Decision Influencers',
#  'Buyer Type > Smooth Buyers',
#  'CPG > Axe',
#  'CPG > Dove',
#  'CPG > Herbal Essences',
#  'CPG > Maxwell House',
#  'CPG > Secret',
#  'Channel > Banner Responder',
#  'Collectibles > Military Memorabilia & Weaponry',
#  'Collectibles > Stamps & Coins',
#  'Company Revenue > $1 - 5 Million',
#  'ConAgra > Peter Pan',
#  'Condition > Used',
#  'Condition > Used Cars',
#  'Consumer In-Market > In-Market Lifestyle & Interests',
#  'Credit Card Holder > MasterCard',
#  'Credit Cards > Millennials - Credit Card Transactor',
#  'Credit Cards > Millennials - Likely to Respond to Credit Card Offer',
#  'Credit Cards > Use Credit Monitoring',
#  'Credit Products and Services > Credit Reporting',
#  'Cross Device Media > Kidney Disease Propensity Caregivers',
#  'Customer Modeled > Apparel',
#  'Customer Modeled > Beauty',
#  'Customer Modeled > Collection',
#  'Customer Modeled > Furniture',
#  'Customer Modeled > Home Improvement DIY',
#  'Customer Modeled > Jewelry',
#  'Customer Modeled > Value Priced',
#  'Decision Drivers & Behavior Motivations > Financially Adventurous',
#  'Decision Drivers & Behavior Motivations > Spontaneous Consumers',
#  'Dedication Spectrum > Hardcore Gamers',
#  'Dedication Spectrum > Mid-core Female Gamers',
#  'Demographics > Renter',
#  'Demographics and Segmentation > Generations',
#  'Dining Out > Fast Food Restaurant Enthusiasts',
#  'Dining Type > Fast Casual Dining',
#  'Downloaded/Streaming > Amazon Prime Instant Video - Last 30 Days',
#  'Economic Cohorts > $100-$200K Income, Age - Young (<35), Charge-It Champs - Young Suburban Families - I43',
#  'Entertainment > DVDs & Videos',
#  'Estimated Home Value (USD) > $100,000 - $199,000',
#  'Estimated Home Value (USD) > $100,000 - $199,999',
#  'Estimated Household Income (USD) > $50,000 - $74,999',
#  'Estimated Household Income (USD) > HHI: $20,000 - $49,999',
#  'Estimated Household Income (USD) > HHI: $40,000-$49,999',
#  'Families with Children > Presence of Child 3-5',
#  'Female > 35-44',
#  'FinTech (Financial Technology) > Cryptocurrencies (incl. Bitcoin)',
#  'FinTech > Cryptocurrency',
#  'Financial Cohorts > <$100K+ Assets, Small Town & Rural - Working Small Town - Conservative Planners - P56',
#  'Flea/Tick Care Prods > Collar',
#  'Flea/Tick Care Prods > Frontline',
#  'Flea/Tick Care Prods > Hartz',
#  'Food & Beverages > Hersheys',
#  'Functional Area > Information Technology',
#  'Genre > Action/Adventure',
#  'Grocery > Frozen Pizza',
#  'Handheld Devices > Tablets',
#  'Health & Beauty > Gillette',
#  'Health & Wellness > Beauty',
#  'Hobbies > Musical Instruments and Performance',
#  'Hobbies, Games & Toys > Musical Instruments',
#  'Hobbies, Games and Toys > Musical Instruments and Performance',
#  'Hockey > Toronto Maple Leafs',
#  'Holiday Shoppers > Toddler Gifts',
#  'Home Market Value > $50,000 - $74,999',
#  'Home Value > $100,000-$199,999',
#  'Home Value > $100,001 to $200,000',
#  'Household Income > $30,000 - $39,999',
#  'Household Income > $40,000 - $49,999',
#  'Household Income > $50,000 - $59,999',
#  'Household Income Range > $60,000-$69,999',
#  'In Market > In Market for Used Vehicle',
#  'In Market > Walmart Shoppers',
#  'In-Market Lifestyle & Interests > Healthy Living',
#  'Income 360 > Millennials - Income Range More than $100,000',
#  'Industry > Software',
#  'Initial Marketing Contact Channel Preference > Twitter',
#  'Insurance Segments > Millennials - Auto Insurance Target',
#  'Insurance Segments > Millennials - High Propensity for Auto Insurance',
#  'Insurance Segments > Millennials - Multiple Insurance Policy Prospects',
#  'Interest (Affinity) > Body Styles',
#  'Interest (Affinity) > Other Vehicles',
#  'Interest > Boating / Sailing',
#  'Interest > Cooking Enthusiasts',
#  'Interest > Motorcycle Enthusiasts',
#  'Interests > Streaming Media & Downloads',
#  'Jeans > Old Navy',
#  'Leisure and Vacation Travelers > Theme Parks',
#  'Length Of Residence > 5 Years',
#  'Length of Residence > 1-4 Years',
#  'Lifestage > Upper Mid Income Families',
#  'Lifestyle Indicator > Fitness Score: Low Caregiver',
#  'Make > Pontiac',
#  'Male > 25-34',
#  'Male > 35-44',
#  'Marketing Content Preference > Video',
#  'Median Home Value > $100,000-$199,999',
#  'Mobile > HH Is Likely to Switch Carrier Next 6 Months and Would Consider Switching to Cricket',
#  'Motorcycles and ATVs > Motorcycles',
#  'Movies > Avatar',
#  'Narrow Age > 35-39',
#  'Narrow Age Range > 35-39',
#  'Nestle > Buitoni',
#  'OTT & CTV > Interests',
#  'Orbits > Price Driven Consumers',
#  'Other Vehicles > Boats',
#  'Pandemic Travel Plans > Likely to Travel Because of New Discounts',
#  'Parents > Single Parent',
#  'Past Purchases > Musical Instruments Recently',
#  "Past Purchases > Women's Plus Sizes Apparel",
#  'Persona > Financially Adventurous',
#  'Personal Care > Shaving Cream',
#  'Preferred Gaming Platforms > Console Only Video Game Players',
#  'Preferred Gaming Platforms > Mobile & PC Video Game Players',
#  'Proctor & Gamble > Gillette',
#  'Products & Services Propensities > Frozen Dinner Buyers - Propensity',
#  'Professional Groups > High Income Professionals',
#  'Professional/Technical > Legal/Education & Training',
#  'Purchase Behaviors > Value-Priced Merchandise',
#  'Restaurants and Dining > Fast Casual Restaurant Diners',
#  'Restaurants and Dining > Millennials - Casual Restaurant Diners',
#  'Self-Classification > The Trade Desk',
#  'Seniority > Executives',
#  'Social Media Users > YouTube',
#  'Sports > Auto/Motorcycle Racing Enthusiasts',
#  'Sports > Hockey',
#  'Style & Fashion > Jeans',
#  'Styles > Plus Size',
#  'Tablets > Amazon Kindle Fire',
#  'Technology & Computing > Tablets',
#  'Technology & Computing > Video Games',
#  'Technology & Software Buyers By Brand > Google',
#  'Technology > I Try Keep Up/Developments in Technology',
#  'Technology > Smart Tech Shopper: Far Above Average',
#  'Telecom & Service Providers > Cricket Wireless Buyer Propensity',
#  'Telecom & Service Providers > Straight Talk Buyer Propensity',
#  'The Trade Desk > Cross Device Media',
#  'Travel > Millennials - Theme Park Visitors',
#  'Vehicle Owners > Millennials - Vehicle Owners',
#  'Video Games > Genre',
#  'WealthCompleteÂ® HD Total Investable Assets > Asset Range $100,000 - $249,999',
#  'Xennials - The First Millennials (Age 31-41) > Home Cooking',
#  'Year > 2005'}

# %%
exclusive_interests['Navigation-TripPlanners']
# Out:
# {'25-29 > Age 26',
#  '25-34 > 25-29',
#  '50-54 > Age 53',
#  'AFS Buckets > 5',
#  'Activities & Interests > Guitar',
#  'Activities & Interests > National News',
#  'Activities and Entertainment > PGA Tour Enthusiasts',
#  'Activity & Event Tickets > Live Theater',
#  'Age > 18-24',
#  'Age > 6-10 Years',
#  'Age of Children in Household (Kids) > Parents of Infants (0-2)',
#  'Age of Children in Household (Kids) > Parents of Infants (Ages 0-2)',
#  'Annual Discretionary Spending on Donation > $2,500 to $3,499',
#  'Apparel > $2,500 to $2,999',
#  'Apparel > ZARA Buyer Propensity',
#  'Auto > Auto Loan 36 Months+',
#  'Automotive > American Auto Association (AAA) Member',
#  'Automotive Owners > Own a Dodge',
#  'Back To School > Affluent Consumer',
#  'Back To School > Consumer with Middle School Aged Kids',
#  'Banking Channel Preference > In Branch Banking',
#  'Big Spending Travel Intenders > Cruise Travel',
#  'Brands > Hallmark/Hallmark Crown',
#  'Brands > Kikkoman',
#  "Brands > Macy's",
#  'Brands > Quaker',
#  'Brands > Safeway',
#  'Broad Age > 21-29',
#  'Business Profession > Blue Collar Business Decision Influencers',
#  'Business Profession > Blue Collar Business Executives',
#  'Business Profession > Blue Collar Business Owners',
#  'Business Profession > White Collar Business Decision Makers',
#  'CPG > Luvs Diapers',
#  'CPG > Pampers',
#  'CPG > Suave',
#  'Cable Provider > Cox Communications',
#  'Car Rental > Alamo',
#  'Celebrities > Celebrity Fan Gossip',
#  'Chevrolet > Chevrolet Camaro',
#  "Children's Products > Learning & Activity Toys",
#  'Company Sales > Small ($200K - $500K)',
#  'Consumer > Home Amenities',
#  'Consumer Behavior > At-Home: Families at Home (Kids Under 13)',
#  'Consumer Behavior > Influenced: Age',
#  'Consumer Behavior > Occupation: Construction/Mining Workers',
#  'Consumer Behavior > Occupation: Government Workers',
#  'Consumer Behavior > Occupation: Retail (Non-food) Workers',
#  'ConsumerSpend Electronics > $1-$99',
#  'ConsumerSpend Entertainment > $1,000-$1,999',
#  'ConsumerSpend Home Furnishings > $1,000-$2,499',
#  'Credit Card Financial Personality > Credit Seeking Card Switcher, High Credit Card Balance',
#  'Credit Card Holder > Premium',
#  'Credit Cards > Mastercard (Regular)',
#  'Current Home Value > $200,000-$249,999',
#  'Dataline > Loan Information',
#  'Dedication Spectrum > Casual Male Gamers',
#  'Demographic > Age',
#  'Demographic > Military Status',
#  'Demographics > Household Estimated Wealth $300,000 - $550,000',
#  'Demographics > Household Income $81,000 - $90,000',
#  'Demographics > Presence of Children Age 0-3',
#  'Deposits Financial Personality > Conservative Branch Banker, Very High Deposit Balance',
#  'Discretionary Spend > Education: $0-$511',
#  'Discretionary Spending > $50,000 - $74,999',
#  'Economic Cohorts > $100-$200K Income, Age - Young (<35), Material World - Urban Families - I47',
#  'Education > $1,500 to $2,499',
#  'Education > Graduate School',
#  'Education > Vocational or Technical School',
#  'Education > Vocational/Tech Degree',
#  'Education Level > Attended Vocational/Technical',
#  'Education Level > Completed Graduate School',
#  'Employment > Military Veteran',
#  'Estimated Household Income > $55,000 - $59,999',
#  'Estimated Net Worth > $100,000 - $249,999',
#  'Events > Live Theater',
#  'Experian - Private > Social Network Behavior',
#  'Families with Children > Parents - Second Time',
#  'Families with Children > Presence of Child 0-2',
#  'Families with Children > Presence of Child 11-15',
#  'Family Composition > Veteran in Household',
#  'Female > 18-24',
#  'Financial > Balance Transfer Index',
#  'Financial Personalities > Mortgage Financial Personality',
#  'Food & Drugstore > Blue Apron Buyer Propensity',
#  'Food and Drink > Mexican Cuisine',
#  'Generations > Female Gen Y',
#  'Genre > Science Fiction (Sci-FI) and Fantasy Movie Streamers',
#  'GreenAware > True Browns',
#  'Group B: Flourishing Families > B07 - Across the Ages',
#  'Group M: Families in Motion > M45 - Growing and Expanding',
#  'Health & Wellness > Fitness',
#  'Health Insurance > United Healthcare Insured (UHC)',
#  'Health Insurance > Unitedhealthcare',
#  'Hobbies & Interests > Golf',
#  'Hobbies, Games & Toys > Toys',
#  'Home & Household Goods > Rooms To Go Buyer Propensity',
#  'Home Amenities > Pool',
#  'Home Market Value > $200,000 - $224,999',
#  'Household Deposits > Tier 2',
#  'Household Income > $125,000-$149,999',
#  'Household Income > $150,000-$174,999',
#  'Household Income Range > $160,000-$179,999',
#  'In Market - Fuel > Used Alternative Fuel',
#  'In Market - Make and Models > Used Toyota',
#  'In Market > Auto Lease - Likely In Market',
#  'In-Market > Furniture - Working Families',
#  'In-Market > Gift Baskets',
#  'In-Market > Home Decor',
#  'In-Market > Home Improvement Families',
#  'In-Market > Kitchen Dining',
#  'Industry > Transportation, Communications, Electric, Gas and Sanitary Services',
#  'Initial Marketing Contact Channel Preference > LinkedIn',
#  'Insurance Financial Personality > Confident, Self-Directed Planner, High Insurance Policy Face Value',
#  'Intenders > Subscribe to Multiple Publications',
#  'Interest (Affinity) > Graduate Schools',
#  'Interest > Collecting Coins',
#  'Interest > High-Tech Innovations',
#  'Interest > Snow Skiing Fan',
#  'Interest Propensities > Food and Drink',
#  'Interest Propensities > Music',
#  'Interest Propensities > Oil & Gas',
#  'Interest Propensities > TV & Movies',
#  'Interests > Owns Swimming Pool',
#  'Investable Assets > Tier 3',
#  'Investable Assets > Tier 4',
#  'Investment Balances > Tier 3',
#  'Investment Balances > Tier 4',
#  'Investment Target Segments > High-Risk Investors',
#  'Investments Financial Personality > Skeptical, Fund-Oriented Investor, Low to Medium Investable Assets',
#  'KIA > KIA Forte',
#  'KIA > KIA Niro',
#  'KIA > Kia Sedona',
#  'KIA > Kia Telluride',
#  'Length Of Residence > 10 Years',
#  'Length Of Residence > 9 Years',
#  'Length Of Residence > Under 1 Year',
#  'Length of Residence > Years: 10-14',
#  'Lifestage > Established High Income Families',
#  'Likely Donors > General Contributor',
#  'Loan Information > Indivuals who have an auto loan',
#  'Military Status > Army',
#  'Moms > Crafty Mothers',
#  'Moms > Mothers with 2+ children',
#  'Mortgage Financial Personality > Conservative, Bank Loyalist, Slightly Below Average Mortgage Balance',
#  'Mortgage Refinance > 03 Very likely to refinance',
#  'Mortgage Refinance > 06 Somewhat unlikely to refinance',
#  'Mortgage Refinance > Likely to refinance',
#  'Mosaic > Group M: Families in Motion',
#  'Movies > Horror',
#  'Movies > Jurassic World',
#  'Music > Classic Rock',
#  'Music > Country',
#  'Music > Hip Hop and Rap',
#  'NFL > New England Patriots',
#  'NHL Teams > Boston Bruins',
#  'Narrow Age > 25-29',
#  'Narrow Age Range > 75-79',
#  'Net Assets Score > $250,000-$499,999',
#  'Neutrogena > NCS+NTG-128+3P_Neutrogena_A_2020_TA-In Category_603451_CP_ACQ_GM_BE-AB_CE-AB_T-R52W -PD603451',
#  'News and Current Events > US News',
#  'Nissan > Nissan Titan',
#  'Number of Adults in Living Unit > 5',
#  'Number of People in Living Unit > 6',
#  'Occupation > Army Credit Union Trades',
#  'Occupation > Lower Management',
#  'Occupation > Manager',
#  'Occupation > Mechanic',
#  'Occupation > Office and Administrative Support',
#  'Occupation > Other',
#  'Oil & Gas > Speedway',
#  'Oil & Gas > Sunoco',
#  'Online Shoppers > Shops for Pet Supplies Primarily Online',
#  'Orbits > Specialty Shoppers',
#  'Ownership - Body Styles > Compact or Subcompact Car',
#  'Ownership - Body Styles > Full-Size Truck',
#  'Ownership - Body Styles > Small Mid-Size SUV',
#  'Ownership - Body Styles > Truck',
#  'Ownership - Body Styles > Van Minivan',
#  'Ownership - Make and Models > Hyundai',
#  'Ownership - Make and Models > Scion',
#  'Ownership - Switch to > Ram',
#  'Podcasts > Google Podcast Listeners',
#  'Preferred Gaming Platforms > All Gaming Platforms',
#  'Preferred Gaming Platforms > Console & PC Video Game Players',
#  'Products & Services Propensities > Professional Baseball Fans - Propensity',
#  'Products & Services Propensities > Rock Concert Attendee - Propensity',
#  'Property/Realty Year Built > 2000-2009',
#  'Purchase Behaviors > Mail Order Buyer',
#  'Purchases > Furniture',
#  'Remote Business Decision Makers & Influencers > Early Adopters of Technology',
#  'Remote Business Decision Makers & Influencers > Prefers Infographic Marketing Content',
#  'Restaurants > Types of Food',
#  'SUVs > Small-Size SUV',
#  'Shoppers All Channels > Home Domestic',
#  'Small Business Assets > Small Business Asset Range $10,000 - $24,999',
#  'Social IQ > Social Media Influencer',
#  'Social Media > Non-traditional Student',
#  'Social Media > Snapchat',
#  'Social Network Behavior > Social IQ',
#  'Sports > Tennis',
#  'Sports Equipment & Outdoor Gear > Exercise & Fitness',
#  'Staggered Age Range > 75+',
#  'State > AZ',
#  'TV & Movies > Horror & Suspense',
#  'TV & Movies > Music TV',
#  'TV & Movies > Network TV',
#  'TV & Movies > News TV',
#  'TV Dayparts > Likely Early Morning Viewers',
#  'Telecom & Service Providers > MetroPCS Buyer Propensity',
#  'Total > $20,000 to $24,999',
#  'Toys > Educational Toys',
#  'Transportation, Communications, Electric, Gas and Sanitary Services > Motor Freight Transportation and Warehousing',
#  'Travel > $4,000 to $4,999',
#  'Travel > Car Rental',
#  'Travel Activities > Fishing',
#  'Travel Type > Traveled for Leisure in last 12 months',
#  'Types of Food > Healthy Food',
#  'Vehicle Make > In Market for a Subaru',
#  'Visa and MasterCard > MasterCard',
#  'WealthComplete Total Investable Assets > Asset Range $250,000 - $499,999',
#  'WealthCompleteÂ® HD Total Investable Assets > Asset Range $500,000 - $749,999'}

# %%
exclusive_interests['Pets-Animals']
# Out:
# {'AFS Buckets > 8',
#  'AcquireWeb - Claritas > Sports and Entertainment',
#  'Active/Interest In > Outdoor',
#  'Affinity Answers > Brands',
#  'Affluence Segments > Climbers',
#  'Age 18-29 > Age 25-29 years',
#  'Age > 19-24',
#  'Age > 3-5 Years',
#  'Agents and Brokers > Insurance',
#  'Agriculture & Natural Resources > Mining, Oil & Gas',
#  'All Categories Frequency > Number of Credit Purchases Total: 3-15',
#  'All Categories Frequency > Number of Purchases Last 3 Months: 5+',
#  'All Categories Recency > Ordered in Last 0-3 Months',
#  'All Categories Recency > Total Dollars 0-3 Months: $352+',
#  'All Categories Recency > Total Dollars 0-3 Months: Dollars Spent: $51-$351',
#  'All Categories Spend > Total Dollars: $1,435+',
#  'All Categories Spend > Total Dollars: $1-$179',
#  'Alliant > Emerging Consumers',
#  'Annual Credit Card Retail Spending > $1,500 - $2,000',
#  'Annual Discretionary Donations > $2,500 - $3,499',
#  'Apparel > JustFab Buyer Propensity',
#  'Apparel > Shoe Carnival Buyer Propensity',
#  'Apparel > Womens Athletic',
#  'Apparel > Zumiez Buyer Propensity',
#  'Auto > Auto Lease 36 Months+',
#  'Auto Buyers > Hyundai',
#  'Auto In The Market > Used Vehicle Age',
#  'Auto Service and Repair > Acura Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Audi Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Bmw Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Bmw Dealership Auto Service Loyalists (IMR)',
#  'Auto Service and Repair > Changes Own AC DIY (IMR)',
#  'Auto Service and Repair > Changes Own Battery Cables DIY (IMR)',
#  'Auto Service and Repair > Changes Own Clutch Parts DIY (IMR)',
#  'Auto Service and Repair > Changes Own Exhaust System DIY (IMR)',
#  'Auto Service and Repair > Changes Own Gaskets DIY (IMR)',
#  'Auto Service and Repair > Changes Own Ignition Parts DIY (IMR)',
#  'Auto Service and Repair > Changes Own Steering Parts DIY (IMR)',
#  'Auto Service and Repair > Changes Own Suspension Parts DIY (IMR)',
#  'Auto Service and Repair > Clean Their Own Fuel System DIY (IMR)',
#  'Auto Service and Repair > Honda Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Mazda Dealership Auto Service Loyalists (IMR)',
#  'Auto Service and Repair > Mercedes-Benz Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Pays for AC Compressor Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Battery Cables Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Battery Change Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Clutch Parts Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Exhaust Pipes Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Fuel Injector Cleaning Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Fuel System Cleaning Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Gasket Repair Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Leak Stopped Repair Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Lubricant Refill DIFM (IMR)',
#  'Auto Service and Repair > Pays for Other Collision Body Part Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for Other Fuel System Part Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for Other Ignition Part Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for Other Lighting Part Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for Other Windshield Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for Power Steering Chemicals Refill DIFM (IMR)',
#  'Auto Service and Repair > Pays for Sensor Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for System Cleaners and Treatments DIFM (IMR)',
#  'Auto Service and Repair > Pays for Transmission Part Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for Water Pump Repair DIFM (IMR)',
#  'Auto Service and Repair > Prospective Aamco Customer (IMR)',
#  'Auto Service and Repair > Prospective Amazon.Com Customer for Vehicle Parts (IMR)',
#  'Auto Service and Repair > Prospective Body Repair Shop Customer (IMR)',
#  'Auto Service and Repair > Prospective Car Quest Customer (IMR)',
#  'Auto Service and Repair > Prospective Costco Customer (IMR)',
#  'Auto Service and Repair > Prospective Foreign Repair Specialist Customer (IMR)',
#  'Auto Service and Repair > Prospective Gas Service Station Customer (IMR)',
#  'Auto Service and Repair > Prospective Government Testing Facility Customer (IMR)',
#  'Auto Service and Repair > Prospective Grease Monkey Customer (IMR)',
#  'Auto Service and Repair > Prospective Just Tires Customer (IMR)',
#  'Auto Service and Repair > Prospective Kmart Customer for Auto Parts or Service (IMR)',
#  'Auto Service and Repair > Prospective Monro Customer (IMR)',
#  'Auto Service and Repair > Prospective Ntb Customer (IMR)',
#  'Auto Service and Repair > Prospective Q Lube/Quaker State Lube Customer (IMR)',
#  "Auto Service and Repair > Prospective Sam's Club Customer (IMR)",
#  'Auto Service and Repair > Prospective Sears Customer (IMR)',
#  'Auto Service and Repair > Prospective Service Station Customer (IMR)',
#  'Auto Service and Repair > Prospective Target Customer for Auto Parts (IMR)',
#  'Auto Service and Repair > Repairs Own AC Parts DIY (IMR)',
#  'Auto Service and Repair > Repairs Own Collision Body Parts DIY (IMR)',
#  'Auto Service and Repair > Repairs Own Fuel System Parts DIY (IMR)',
#  'Auto Service and Repair > Repairs Own Painting DIY (IMR)',
#  'Auto Service and Repair > Replace Own Transmission Parts and Repairs DIY (IMR)',
#  'Auto Service and Repair > Shops at Big O (IMR)',
#  'Auto Service and Repair > Toyota Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Uses Yokohama Tires (IMR)',
#  'Automobile Types > Full-sized Cars',
#  'Automotive Owners > Own a Nissan',
#  'Automotive Owners > Own a Volkswagen',
#  'Aveeno > NCS+AVO-170+3P_Aveeno_Positively Radiant_2021_TA-In Category_795610_CP_ACQ_GM_BE-AB_CE-AB_T-R52W -PD795610',
#  'Average Bank Card Balance Transfer Amount > $3,000-$3,249',
#  'Average Bank Card Balance Transfer Amount > $3,250-$3,499',
#  'Back To School > Consumer with Elementary School Aged Kids',
#  'Back to School > Elementary',
#  'Behavior Model > Credit Card',
#  'Beverages > Energy & Sports Drinks',
#  'Big Tech > Microsoft',
#  'Books & Magazines > Religious & Inspirational',
#  'Brand Segment > Coke',
#  'Brand Segment > Kraft',
#  'Brands > Cherry Coke',
#  'Brands > Giant Food Stores',
#  'Brands > Scott Tissue',
#  'Brands > Sears',
#  'Brands > Toys & Games',
#  'Browser Activity > News',
#  'Business Profession > Insurance Business Decision Influencers',
#  'Business Services > Lodging - Hotels & Resorts',
#  'Car Attitude > Quality of Workmanship/Construction',
#  'Card Holders > Visa Card Holder',
#  'Card Holders > Visa Card Super Shoppers',
#  'Caregiver by Age > Caregiver Age 50-59',
#  'Caregiver by Caregivee HHI > Caregivee HHI $50,000-$99,999',
#  'Caregiver by Caregivee Relationship > Parent Caregivers',
#  'Caregiver by Caregivee Relationship > Spouse Caregivers',
#  'Caregiver by HHI > Caregiver HHI $50,000-$99,999',
#  'Children Merchandise > Dollars Spent: Mid-Level Spender',
#  'Children in Household > 5',
#  "Children's Product Purchases > General",
#  'Clorox > Clorox',
#  'Coke > Powerade',
#  'Collectors > Movies',
#  'Companies by Annual Revenue/Sales Volume > $10,000,000 - $50,000,000',
#  'Companies by Annual Revenue/Sales Volume > $5,000,000 - $10,000,000',
#  'Companies by Annual Revenue/Sales Volume > $50,000,000 - $100,000,000',
#  'Companies by Annual Revenue/Sales Volume > $500,000,000 - $1 Billion',
#  'Companies by Employee Size > Emerging (10-19)',
#  'Companies by Employee Size > Large (2,500-4,999)',
#  'Companies by Employee Size > Medium (500-999)',
#  'Companies by Employee Size > Medium-Large (1,000-2,499)',
#  'Companies by Employee Size > Micro+ (20-49)',
#  'Companies by Employee Size > Small (50-99)',
#  'Companies by Employee Size > Small-Medium (100-499)',
#  'Companies by Location > Mountain Region',
#  'Company Industry > Arts, Entertainment and Recreation',
#  'Company Industry > Business and Professional Services',
#  'Company Industry > Construction',
#  'Company Industry > Hospitality and Food Service',
#  'Company Industry > Mining, Oil and Gas',
#  'Company Industry > Personal and Consumer Services',
#  'Company Industry > Transportation and Storage',
#  'Company Industry > Wholesale and Retail Trade',
#  'Company Sales Volume (Annual Revenue) > $5,000,000-$10,000,000',
#  'Company Sales Volume (Annual Revenue) > $50,000,000-$100,000,000',
#  'Company Size > 1,000-5,000 Employees',
#  'Company Size > 10-50 Employees',
#  'Company Size > 100-500 Employees',
#  'Company Size > 50-100 Employees',
#  'Company Size > 500-1,000 Employees',
#  'Composite Segments (Audience Clusters) > Loyal Super Spenders',
#  'Connexions > 50 Early-Bird TV',
#  'Construction & Architecture > Contracting & Trade',
#  'Construction > General Building Contractors - Nonresidential',
#  'Construction > General Building Contractors - Residential',
#  "Consumer > Children's Product Purchases",
#  'Consumer > Collectors',
#  'Consumer > Credit Cards',
#  'Consumer Behavior > At-Home: Single Adults',
#  'Consumer Behavior > Generational Segments: Generation Z',
#  'Consumer Behavior > Necessity Consumers',
#  'Consumer Services > Salon & Spa',
#  'ConsumerSpend Clothing > $1,000-$1,999',
#  'ConsumerSpend Clothing > $500-$999',
#  'ConsumerSpend Dining Out > $1,000-$1,999',
#  'ConsumerSpend Electronics > $100-$499',
#  'ConsumerSpend Travel > $2,000-$4,999',
#  'Contracting and Tradesmen > General Contractors and Builders',
#  'Convenience & Gas > Cumberland Farms Buyer Propensity',
#  'Convenience & Gas > Wawa Buyer Propensity',
#  'Credit Card > Credit Card User',
#  'Credit Cards > In-Market',
#  'Credit Cards > Upscale Retail Credit Card',
#  'Credit Cards > Visa Regular',
#  'Current Home Value > $350,000-$499,999',
#  'Customer Modeled > Music',
#  'Demographics > Age 18-29',
#  'Demographics > Education - Did Not Graduate High School',
#  'Demographics > Households with Young Children Ages 5 to 12',
#  'Demographics > Males',
#  'Demographics > Self-Reported Excellent Credit',
#  'Department/Discount/Warehouse Stores > Ace Hardware',
#  "Department/Discount/Warehouse Stores > Lowe's",
#  'Deposits Financial Personality > Hesitant Borrower, Low Deposit Balance',
#  'Discretionary Spend > All Categories $7,901-$10,930',
#  'Discretionary Spend > Travel: $682-$1,364',
#  'Dwelling Type > Multi-Unit Residential Home',
#  'Dwelling Type > Multi-family w/o Apt #',
#  'Dwelling Unit Size > 101+ Units',
#  'Economic Cohorts > $100-$200K Income, Age - Pre-Retirement (55-64), Planners and Savers - Suburban Couples - K57',
#  'Education > Less than High School Diploma',
#  'Engineering > Research & Scientific',
#  'Entertainment > Amusement & Recreation',
#  'Entertainment > Comic Books',
#  'Entertainment > Disney',
#  'Entertainment > Football',
#  'Entertainment > Nerdy Pop Culture',
#  'Entertainment > Reality TV',
#  'Entertainment > Starz',
#  'Entertainment > YouTube',
#  'Estimated Net Worth > $750,000 to $999,999',
#  'Families with Children > Presence of Child 6-10',
#  'Family Position > Female Head of Household',
#  'Fast Food Diners > Burger King',
#  "Fast Food Diners > McDonald's",
#  "Fast Food Diners > Wendy's",
#  'Female > 45-54',
#  'Financial > Chase Customer (Scarborough)',
#  'Financial > Citibank Customer (Scarborough)',
#  'Financial > In Market Credit Card',
#  'Financial > Prospective GEICO Auto Insurance Buyer (Scarborough)',
#  'Financial > Prospective Mercury Auto Insurance Buyer (Scarborough)',
#  'Financial Cohorts > Less Than $100K+ Assets, Small City - Moderate Income - Beginning to Invest - M47',
#  'Financial Products and Services > Credit Cards',
#  'First Time Homebuyer > Yes',
#  'Food & Drugstore > Lindt & Sprungli Buyer Propensity',
#  'Food & Drugstore > Wegmans Buyer Propensity',
#  'Food and Dining > Casual Restaurant',
#  'Football > Attend NFL Regularly',
#  'Ford > Flex',
#  'Ford > Ford Taurus',
#  'Ford > Taurus',
#  'Frequent Flyer Programs > Not Enrolled in Frequent Flyer Program',
#  'Grocery > Iced Tea',
#  'Grocery > Sugar Substitutes',
#  'Group O: Singles and Starters > O51 - Digitally Savvy',
#  'Group O: Singles and Starters > O55 - Family Troopers',
#  'Head of Household > Female Head of Household',
#  'Health > Dollars Spent: Mid-Level Spender',
#  'Health > Power Spender',
#  'Health > Prospective Health Net Health Insurance Buyer (Scarborough)',
#  'Health > Shops Target Pharmacy (Scarborough)',
#  'Health and Wellness > 5+ Hour Walkers',
#  'Hobbies & Interests > Travel Enthusiasts',
#  'Home Equity Financial Personality > Uninterested, Low Home Equity Balance',
#  'Home Goods: Kitchen > Dollars Spent: Mid-Level Spender',
#  'Home Market Value > $225,000 - $249,999',
#  'Home Office > Dollars Spent: Mid-Level Spender',
#  'Home Office > Power Spender',
#  'Home Type > Apartment',
#  'Home Value > $200,000- $399,999',
#  'Home Value > $200,000-$299,999',
#  'Home Value Range > $200 - $250k',
#  'Homeowner/Renter > Renter',
#  'Hospitality & Food Services > Restaurants & Catering',
#  'Hospitality and Food Service > Accommodation',
#  'Hospitality and Food Service > Restaurants',
#  'Hotels for Any Travel > Traveler - Choice',
#  'Household Deposits > Tier 5',
#  'Household Income > $50,000 - $74,999',
#  'Household Income > $50,000-$59,999',
#  'Household Income > $50,000-$74,999',
#  'Household Income > $60,000-$74,999',
#  'Household Income Range > $40,000-$44,999',
#  'Household Products > Brands',
#  'In-Market Segments > In-Market for New Mini Van',
#  'In-Market Segments > In-Market for New Wagon',
#  'Industries & Occupations > Agriculture & Natural Resources',
#  'Industries & Occupations > Construction & Architecture',
#  'Industries & Occupations > Hospitality & Food Services',
#  'Industries & Occupations > Personal & Consumer Services',
#  'Industries & Occupations > Science & Engineering',
#  'Insurance Financial Personality > Engaged Advice Seeker, Average Insurance Policy Face Value',
#  'Interests > Childrens Products',
#  'Interests > Clothing',
#  'Interests > Consumer Electronics',
#  'Interests > Cosmetics',
#  'Interests > Electronics/Internet/Computer Games',
#  'Interests > Fashion',
#  'Interests > Health Beauty Products',
#  'Interests > Personal Development',
#  'Interests > Religion',
#  'Interests > Sports',
#  'Interests > Truck Owner',
#  'Investable Assets > Tier 6',
#  'Investment Balances > Tier 5',
#  'J&J > Zyrtec Base 2021 Brand Buyer -PD776979',
#  'Jewelry/Accessories > Dollars Spent: Heavy Spender',
#  'Kraft > Dr Pepper',
#  'Landline Loyalists > Longtime Subscriber With Charter',
#  'Landline Loyalists > Longtime Subscriber With Comcast',
#  'Landline Loyalists > Longtime Subscriber With Cox',
#  'Landline Switcher > Predicted to Switch from Comcast',
#  'Landline Switcher > Predicted to Switch from Cox',
#  'Landline Switcher > Predicted to Switch to Comcast',
#  'Length of Residence > 6-10 Years',
#  'Lifestage > Established Lower Mid Income Families',
#  'Likely Device or Viewing Method > Likely to Use DVR',
#  'Likely Device or Viewing Method > Likely to View TV content on a Television',
#  'MLB Teams > Cincinnati Reds',
#  'MLB Teams > Cleveland Indians',
#  'Makes & Models > Nissan',
#  'Makes & Models > Volkswagen',
#  'Manufacturing > Chemicals & Allied Products',
#  'Manufacturing > Food & Beverage',
#  'Manufacturing > Food and Beverages',
#  'Media & Entertainment > Half Price Books Buyer Propensity',
#  'Media Involvement > TV Involvement',
#  'Mortgage > Refinance Type',
#  'Mosaic > Group O: Singles and Starters',
#  'Multiple Family > Apartment',
#  'Music > Listens to Alternative Music',
#  'NFL > Buffalo Bills',
#  'NFL > Cleveland Browns',
#  'Narrow Age Range > 30-34',
#  'Net Worth > $100,000 - $149,999',
#  'Net Worth > $50,000 - $99,999',
#  'Neutrogena > HB FMT or Cleansing Buyers -PD777213',
#  'Neutrogena > NCS+NTG-293+3P_Neutrogena_Rapid Tone Repair_2021_TA-In Category_795640_CP_ACQ_GM_BE-AB_CE-AB_T-R52W -PD795640',
#  'News > CNN',
#  'News > Local',
#  'News > National',
#  'News > Newspapers',
#  'Nissan > Stanza',
#  'Number of Adults > 1',
#  'Number of Children > One',
#  'Number of People in Living Unit > 5',
#  'Occupation > Insurance/Agent',
#  'Occupation > Sales',
#  'Occupations and Job Functions > Agents and Brokers',
#  'Occupations and Job Functions > Contracting and Tradesmen',
#  'Occupations and Job Functions > Engineering and R&D',
#  'Outdoor > Outdoor Enthusiast',
#  'P$YCLE Premier > 49 Penny Pinchers',
#  'PRIZM Premier > 40 Aspiring A-Listers',
#  'Parents > Working Parents',
#  'Past Purchases > Gardening or Farming Products',
#  'Persona > Open to Diversity',
#  'Personal Care > Body Wash',
#  'Personal Development > Online Education',
#  'Personal Finance Profile > Smart Investor: Far Above Average',
#  'Personal Views > Social Isolation',
#  'Pet Care > Dog Food & Supplies',
#  'Pet Care > Dog Food and Supplies',
#  'Pets > Wet Dog Food Model',
#  'PreMovers > Renters',
#  'Proctor & Gamble > Old Spice',
#  'Proctor & Gamble > Secret',
#  'Production & Manufacturing > Food & Beverages',
#  'Products & Services Propensities > Cat Product Buyer - Propensity',
#  'Professionals by Department/Functional Area > Engineering',
#  'Professionals by Industry > Business Services',
#  'Professionals by Industry > Construction',
#  'Professionals by Industry > Consumer Services',
#  'Professionals by Industry > Entertainment',
#  'Professionals by Industry > Membership Organizations',
#  'Professionals by Industry > Political Organizations',
#  'Professionals by Industry > Retail',
#  'Professionals by Industry > Transportation',
#  'Property Type > Multiple Family',
#  'Property/Realty Year Built > 1980-1989',
#  'Purchase Behaviors > Online Education',
#  'Purchase Behaviors > Religious',
#  'Purchase Behaviors > Sports & Leisure',
#  'Purchases > Apparel',
#  "Purchases > Apparel, Women's",
#  "Purchases > Children's, General",
#  'Purchases > Collectibles',
#  'Purchases > Crafts',
#  'Purchases > Female-Oriented Products/Services',
#  'QSR > White Castle Buyer Propensity',
#  'Refinance Type > Adjustable',
#  'Restaurants & Dining > Bob Evans Buyer Propensity',
#  'Restaurants & Dining > Cracker Barrel Buyer Propensity',
#  'Restaurants & Dining > Ruby Tuesday Buyer Propensity',
#  'Restaurants & Dining > TGI Fridays Buyer Propensity',
#  'Restaurants & Dining > Texas Roadhouse Buyer Propensity',
#  'Retail > Restaurants',
#  'Retail > Shop at Bj Wholesale Club (Scarborough)',
#  "Retail > Shop at Bloomingdale's (Scarborough)",
#  'Retail > Shop at Macys (Scarborough)',
#  'Retail > Shop at Marshalls (Scarborough)',
#  'Retail > Shop at Neiman Marcus (Scarborough)',
#  'Retail > Shop at Nordstrom (Scarborough)',
#  'Retail > Shop at Nordstrom Rack (Scarborough)',
#  'Retail > Shop at REI (Scarborough)',
#  'Retail > Shop at Saks Fifth Avenue (Scarborough)',
#  'Retail > Shop at Target for Athletic Goods (Scarborough)',
#  'Retail > Shops BJs Wholesale Club (Scarborough)',
#  'Retail > Shops Online Grocery (Scarborough)',
#  "Retail > Shops Trader Joe's (Scarborough)",
#  'Retail > Shops Whole Foods Market (Scarborough)',
#  'Retail > Shops at Ann Taylor (Scarborough)',
#  'Retail > Shops at Anna Linens (Scarborough)',
#  'Retail > Shops at Anthropologie (Scarborough)',
#  'Retail > Shops at BJs Wholesales Club (Scarborough)',
#  'Retail > Shops at Banana Republic (Scarborough)',
#  'Retail > Shops at Bloomingdales (Scarborough)',
#  'Retail > Shops at Brooks Brothers (Scarborough)',
#  'Retail > Shops at Crate and Barrel (Scarborough)',
#  'Retail > Shops at Gap (Scarborough)',
#  'Retail > Shops at Lady Foot Locker (Scarborough)',
#  'Retail > Shops at Lord and Taylor (Scarborough)',
#  'Retail > Shops at Macy (Scarborough)',
#  'Retail > Shops at Marshalls (Scarborough)',
#  'Retail > Shops at Neiman Marcus (Scarborough)',
#  'Retail > Shops at New York and Company (Scarborough)',
#  'Retail > Shops at Nordstrom Rack (Scarborough)',
#  'Retail > Shops at Old Navy (Scarborough)',
#  'Retail > Shops at REI (Scarborough)',
#  'Retail > Shops at Staples (Scarborough)',
#  'Retail > Shops at The Container Store (Scarborough)',
#  'Retail Transactions > Health',
#  'Retail Transactions > Home Office',
#  'Sales > Retail',
#  'Sales Volume > $5,000,000-$10,000,000',
#  'Sales Volume > $50,000,000-$100,000,000',
#  'Samsung > Samsung Galaxy S6',
#  'Seasonal > Black Friday Consumer',
#  'Seasonal > Cyber Monday Consumer',
#  "Seasonal > Father's Day Consumer",
#  "Seasonal > New Year's Consumer",
#  "Seasonal > Presidents' Day Consumer",
#  'Shoppers All Channels > Lawn/Garden',
#  'Shoppers All Channels > Seasonal Products',
#  "Shopping > Women's Product Shoppers",
#  'Sports & Recreation > Motor Sports',
#  'Sports > Winter Olympics Games Fans',
#  'Sports and Entertainment > Attends Art Museum (Scarborough)',
#  'Staggered Age Range > 25-34',
#  'State > UT',
#  'Tech > Above Average Technology Users',
#  'Tech > High Tech Users',
#  'Tech > Prospective Sprint Cell Phone Service Subscriber',
#  'Tech > Sprint Cell Phone Service Subscriber',
#  'Technology Adoption > Early Majority',
#  'Technology Adoption > Top 25% for Tech',
#  'Telco Subscribers > Landline Loyalists',
#  'Telco Subscribers > Landline Switcher',
#  'Telecom & Service Providers > DISH Buyer Propensity',
#  'Top 25% for Tech > Technology Adoption',
#  'Toys & Games > Mario Kart (Franchise)',
#  'Transportation > Motor Freight & Warehousing',
#  'Transportation > Pipelines',
#  'Transportation > United States Postal Service',
#  'Transportation and Storage > Postal and Courier Activities',
#  'Travel > Cedar Point Buyer Propensity',
#  'Travel > Planning to Visit a Disney Theme Park',
#  'Used Vehicle Age > 6-10 Years',
#  'Vehicle Type > Hatchback Owners',
#  'Video Games > Console Games',
#  'Volkswagen (VW) > Volkswagen Passat',
#  'Volkswagen > Passat',
#  'Volkswagen > Volkswagen Passat',
#  'WealthComplete Deposits > Deposit Range $50,000 - $99,999',
#  'WealthComplete Total Investable Assets > Asset Range $25,000 - $49,999',
#  'WealthCompleteÂ® HD Total Investable Assets > Asset Range $250,000 - $499,999',
#  'Wholesale and Retail Trade > Retail Trade',
#  'Wireless Switcher > Predicted to Switch from Us Cellular to Verizon',
#  "Women's Athletic Apparel > Dollars Spent: Heavy Spender",
#  "Women's Mid-Price Apparel > Dollars Spent: Mid-Level Spender"}

# %%
exclusive_interests['Fashion-Style']
# Out:
# {'25-34 > 30-34',
#  '45-54 > 45-49',
#  '50-54 > Age 50',
#  'AFS Buckets > 2',
#  'Active - 24 Months > Home Decor & Crafting',
#  'AdAdvisor - Private > Neustar AdAdvisor Custom',
#  'Age > 35 - 39',
#  'Age Narrow > 30-34',
#  'Age Narrow > 45-49',
#  'Age Narrow > Ages 30-34',
#  'Age Narrow > Ages 45-49',
#  'Age Range > 35-44',
#  'Ailments - Treatments > Respiratory',
#  'All Categories Recency > Ordered in Last 7-12 Months',
#  'All Categories Recency > Total Dollars Last 7-9 Months: $1-$36',
#  'AmeribaseDigital > Device Tracker - Mobile Location Data',
#  'Annual Credit Card Spending on Travel, Entertainment and Dining > $1,500 - $2,000',
#  'Apparel > Casual Male XL Buyer Propensity',
#  'Arts & Entertainment > Sweepstakes',
#  'Auto Buyers > BMW',
#  'Automotive > Napa Auto Parts Buyer Propensity',
#  'Automotive Owners > Hybrid Cars Propensity',
#  'Baby & Toddler > Baby Wipes',
#  'Back to School > Moms with College Students',
#  'Big Spending Travel Intenders > International Travel',
#  'Black Friday > Black Friday Shoppers – Shopping for Home Furnishings',
#  'Brand Segment > General Mills',
#  'Brands > American Express',
#  'Brands > Stop & Shop',
#  "Brands > Trader Joe's",
#  'Brands > Visine',
#  'Brands > Whole Foods',
#  'Broad Age > 40-49',
#  'Business Owners > Woman-Owned Businesses/Female Business Owners',
#  'Business Profession > White Collar Business Executives',
#  'Business Profession > White Collar Business Owners',
#  'Buyers > Gourmet Products',
#  'Buyers > Holiday Products',
#  'Buyers > Sewing & Needlecraft Items',
#  'CPG > Coffee Mate',
#  'CPG > Haagen Dazs',
#  'Card Holders > American Express Card Holder',
#  'Card Holders > American Express Card Super Shoppers',
#  'Cars > Hatchbacks',
#  'Casual Wear > Khaki',
#  'Chevrolet > Chevrolet Bolt EV',
#  'Children Age Groups > 42531',
#  'Classes > Minivans',
#  'Coffee > Coffee Shop Lovers',
#  'Coffee > Starbucks',
#  'Collectibles > Dollars Spent: Heavy Spender',
#  'Collecting > Art and Antiques',
#  'College Teams > Florida Gators',
#  'College Teams > Florida State Seminoles',
#  'Communication Channel Preference > Cell',
#  'Composite Segments (Audience Clusters) > Affluent Men Shoppers',
#  'Consumer Behavior > Isolating Consumers',
#  'Consumer Behavior > Occupation: Small Business Owners',
#  'ConsumerSpend Travel > $10,000+',
#  'Convenience & Gas > Citgo Buyer Propensity',
#  'Credit Card Holder > American Express',
#  'Credit Cards > AMEX Card',
#  'Credit Cards > Brands',
#  'Cuisine Type > Chinese Cuisine',
#  'Cuisine Type > Italian Cuisine',
#  'Cuisine Type > Southern Cuisine',
#  'Current Home Value > $750,000-$999,999',
#  'Customer Modeled > Donors',
#  'Customer Modeled > Education',
#  'Customer Modeled > Electronics',
#  'Customer Modeled > Membership',
#  'Customer Modeled > Professionals',
#  'Cyber Monday > Cyber Monday Shoppers – Shopping for Home Furnishings',
#  'Dataline > Home Ownership',
#  'Demographics & Segmentation > Children Age Groups',
#  'Demographics & Segmentation > Presence of Children',
#  'Demographics > Family - Grandparent in Household',
#  'Demographics > Household Estimated Wealth $550,000 - $1000,000',
#  'Demographics > Household Income $121,000 - $130,000',
#  'Demographics > Length of Residence 1 year or less',
#  'Demographics > Presence of Children Age 8-12',
#  'Device Ownership > Smart Home',
#  'Device Tracker - Mobile Location Data > Auto Dealerships',
#  'Discretionary Spend > Entertainment Audio Visual: $952-$1,763',
#  'Discretionary Spend > Entertainment Fees/Admissions: $833-$99,999',
#  'Discretionary Spend > Entertainment Other: $1,974-$99,999',
#  'Discretionary Spend > Entertainment: $4,607-$99,999',
#  'Discretionary Spending > $100,000 - $200,000',
#  "Donation Motivations > Children's Charity Donors",
#  'Dwelling Type > Apartment/Multi Family',
#  'Economic Cohorts > $100-$200K Income, Age - Working Years (35-54), Suburban Success - Upscale Singles and Couples - J54',
#  'Economic Spectrum > Emerging Affluent - Power Spenders',
#  'Electronics > Otterbox Buyer Propensity',
#  'Electronics > iRobot Buyer Propensity',
#  'Entertainment & Pastimes > History Buffs',
#  'Entertainment & Pastimes > Outdoor & Nature Lovers',
#  'Estimated Discretionary Income Percent > 20 - 29%',
#  'Estimated Home Value (USD) > $800,000 - $999,999',
#  'Estimated Household Income (USD) > HHI: $250,000 - $499,999',
#  'Estimated Net Worth > $500,000 - $749,999',
#  'Exercise > Extreme Exercisers',
#  'Eye & Vision > Vision Care & Conditions',
#  "Family Restaurant & Steak House > Denny's",
#  'Family Restaurant & Steak House > Pizza Hut',
#  'Fast Food & Drive-in Restaurant > Coffee',
#  'Fast Food Diners > Subway',
#  'Financial > LifeLock Buyer Propensity',
#  'Financial Cohorts > $100K - $1MM Assets, Age 35-54, Major Metro - Rising Stars - Investors - F24',
#  'Food & Drugstore > Acme Buyer Propensity',
#  'Food & Drugstore > Duane Reade Buyer Propensity',
#  'Food & Drugstore > Five Below Buyer Propensity',
#  'Food & Drugstore > Freshly Buyer Propensity',
#  'Food & Drugstore > Grubhub Buyer Propensity',
#  'Ford > Ford C Max',
#  'General Mills > Haagen-Dazs',
#  'Generations > Male Baby Boomers',
#  'Genre > Animation Movie Streamers',
#  'Genre > Children and Family Movie Streamers',
#  'Genres > Jazz and R&B',
#  'Genres > Latin Music',
#  'Group B: Flourishing Families > B10 - Cosmopolitan Achievers',
#  'HHI: Greater than $250,000 > HHI: $250,000-$399,999',
#  'Health & Diet > Beauty Buffs',
#  'Health & Diet > Health Nut',
#  'Health / Beauty & Cosmetics > Beauty Bar Buyer Propensity',
#  'Health / Beauty & Cosmetics > CityMD Buyer Propensity',
#  'Health / Beauty & Cosmetics > Nutrisystem Buyer Propensity',
#  'Health Insurance > Kaiser Permanente',
#  'Hobbies & Interests > Weight Training',
#  'Holiday > Halloween',
#  'Holiday > Pre Thanksgiving Shoppers',
#  'Holiday/Christmas Shoppers > Home Electronics',
#  'Home & Household Goods > Blick Art Materials Buyer Propensity',
#  'Home & Household Goods > Harbor Freight Tools Buyer Propensity',
#  'Home & Household Goods > Kohler Buyer Propensity',
#  'Home & Household Goods > Moen Buyer Propensity',
#  'Home & Household Goods > True Value Buyer Propensity',
#  'Home & Household Goods > Vistaprint Buyer Propensity',
#  'Home Market Value > $450,000 - $499,999',
#  'Home Ownership > Homeowners',
#  'Home Value > $800,001 to $1,000,000',
#  'Home Value Range > $500 - $550k',
#  'Homeownership > Renter',
#  'Honda > Odyssey',
#  'Hotel Preference > Hilton hotels',
#  'Hotels for Any Travel > Traveler - IHG',
#  'Hotels for Business Travel > Business Traveler',
#  'Household Income Range > $180,000+',
#  'Hyundai > Hyundai Ioniq',
#  'Income > $85,000-$89,999',
#  'Industry > Wholesale Trade',
#  'Industry > Wholesalers',
#  'Insurance Financial Personality > Secure Agent-Oriented Loyalist, High Insurance Policy Face Value',
#  'Intenders > Arts & Craft Supplies',
#  'Intenders > Flowers as a Gift',
#  'Intenders > Party Goods & Supplies',
#  'Intenders > Pre-Made Crafts',
#  'Interest > Antique Art',
#  'Interest > Art',
#  'Interest > Parenting',
#  'Interests > Epicurean',
#  'Interests > Running',
#  'Interests > Tinker DIY',
#  'Investable Assets > Tier 1 (Highest)',
#  'Investing > Has Financial Investments',
#  'Investing > Has Investments',
#  'Investing > Has Personal Investments',
#  'Investing > Personal',
#  'Investment Target Segments > High Propensity for IRA Rollover',
#  'Investor IQ > Invested Assets: $107,000-$999,999',
#  'Jeep > Grand Cherokee',
#  'Jeep > Jeep Grand Cherokee',
#  'Jeep > Patriot',
#  'Jeep > Wrangler',
#  'Jewelry > Omega Buyer Propensity',
#  'Job Function > Construction',
#  'Job Function > Finance',
#  'Job Function > Financial Services/Insurance/Real Estate',
#  'Job Function > Healthcare',
#  'Job Function > Healthcare Workers',
#  'Job Function > Sales & Marketing',
#  'Job Function > Services',
#  'Job Function > Transportation/Communications/Utilities',
#  'Leisure Activities/Hobbies > Cyclist',
#  'Leisure Activities/Hobbies > Home Gardeners',
#  'Leisure Activities/Hobbies > Water Sports Enthusiasts',
#  'Length of Residence > 15-19 Years',
#  'Length of Residence > Years: 15-19',
#  'Lifestage > High Income Adults',
#  'Likely Programming and Content Preferences > Likely to Cable TV Viewers',
#  'MLB Teams > Detroit Tigers',
#  'MLB Teams > Miami Marlins',
#  'Make > Acura',
#  'Media & Entertainment > Blurb Buyer Propensity',
#  'Media & Entertainment > Duolingo Buyer Propensity',
#  'Media & Entertainment > Ny Times Buyer Propensity',
#  'Median Home Value > $900,000-$999,999',
#  'Medical Utilization > Likely to Need and Wear Prescription Glasses',
#  'Medical Utilization > Likely to Need and Wear Reading Glasses',
#  'Mobile Location Audiences > Health & Diet',
#  'Mobile Location Audiences > Hotels for Business Travel',
#  'Mobile Location Audiences > Job Function',
#  'Mobile Location Audiences > Movies',
#  'Mobile Location Audiences > Pet Ownership',
#  'Mobile Location Audiences > Shopping',
#  'Mobile Location Audiences > Travel Frequency',
#  'Mobile Service Provider > Mobile Phone Buyer - Verizon',
#  'Mortgage Refinance > 08 Highly unlikely to refinance',
#  'Movies > James Bond',
#  'Movies > Star Wars',
#  'Music > Jazz Music',
#  'Music > Jazz and R&B',
#  'Music Lovers > Jazz & Blues Music Fan',
#  'Music Lovers > Urban Music fan',
#  'NFL > New York Giants',
#  'NFL > Oakland Raiders',
#  'NFL > San Francisco 49ers',
#  'NFL > Tampa Bay Buccaneers',
#  'Net Worth > $499,999+',
#  'Net Worth > $500,000 - $749,999',
#  'Net Worth > $750,000 - $999,999',
#  'Neustar AdAdvisor Custom > Aspiring Urbanites',
#  'Nissan > Armada',
#  'Nissan > Juke',
#  'Nissan > Murano',
#  'Nissan > Nissan Juke',
#  'Nissan > Pathfinder',
#  'Nissan > Rogue',
#  'Nissan > Sentra',
#  'Number of Adults in Living Unit > 3',
#  'Occupation > Professional',
#  'Occupation > Security',
#  'Olympic Sports > Olympic Track & Field',
#  'Online Donor > Most Likely',
#  'Overall Investable Assets > Top 6% - 10%',
#  'Ownership - Body Styles > Alternate Fuel Car',
#  'Ownership - Body Styles > Mid-Size Car',
#  'Ownership - Make and Models > Toyota Prius Prime',
#  'Ownership - Make and Models > Toyota Sequoia',
#  'Paper, Plastic and Storage > Foils, Wraps, Liners and Baking Pans Purchasers',
#  'Parents > Parents of Pre-School Kids: Age 3-5',
#  'Parents > Parents of Toddlers: Age 1-2',
#  'Personal Care > Brands',
#  'Personal Care and Beauty Products > Feminine Care Purchasers',
#  'Personal Finance > Life Insurance',
#  'Personal Finance > Retirement Planning',
#  'Personal Finance Profile > Smart Investor: Average',
#  'Personas for Health > Learning the System - Pearls and PURLS',
#  'Pet Owners > Pet Owners (Other)',
#  'Pet Ownership > Pet Lover',
#  'Presence of Child > Age: 16-18',
#  'Property/Realty Year Built > 1970-1979',
#  'Purchase Behaviors > Online Purchases',
#  'Purchase Behaviors > Parenting',
#  'QSR > Golden Corral Buyer Propensity',
#  'Remote Business Decision Makers & Influencers > Prefers eBook Marketing Content',
#  'Respiratory > Nasal Allergies',
#  'Restaurants & Dining > Boston Market Buyer Propensity',
#  'Restaurants & Dining > By CHLOE Buyer Propensity',
#  'Restaurants & Dining > Seamless Buyer Propensity',
#  'Restaurants & Dining > Sweetgreen Buyer Propensity',
#  'Restaurants and Dining > Fine Casual Restaurant Diners',
#  'Retail Stores > Best Buy',
#  'Retail Stores > Target',
#  'Sales > Wholesale',
#  "Seasonal Audiences > Father's Day",
#  'Seasonal Audiences > Horse racing/ Derby Day enthusiasts',
#  'Seasonal Audiences > March Madness',
#  'Seasonal Audiences > Superbowl',
#  'Seasonal Audiences > US Open',
#  'Seasonal Audiences > World Cup',
#  'Shopper Segments > Fashion Shoppers',
#  'Shopping > Luxury Lifestyle',
#  'Shopping > Self Pamperer',
#  'Sleep > Good Sleep Quality',
#  'Small Business Assets > Small Business Asset Range $100,000 - $249,999',
#  'Social Networks > Houzz Influencers',
#  'Special Events > Boston Marathon',
#  'Sports > NCAA March Madness',
#  'Sports > NFL Super Bowl',
#  'Sports Interests > NCAA Basketball Fan',
#  'Sports Interests > NCAA Football Fan',
#  'State > CA',
#  'Studios > Lionsgate Streamers',
#  'Telecom & Service Providers > Boingo Wireless Buyer Propensity',
#  'Telecom & Service Providers > Time Warner Cable Buyer Propensity',
#  'Telecom & Service Providers > UrbanSitter Buyer Propensity',
#  'Toyota > 4Runner',
#  'Toyota > Corolla',
#  'Toyota > Highlander',
#  'Toyota > RAV4',
#  'Toyota > Toyota Corolla',
#  'Toyota > Toyota Highlander',
#  'Toyota > Toyota Prius',
#  'Toyota > Toyota Prius Prime',
#  'Toyota > Toyota RAV4',
#  'Toyota > Toyota Yaris',
#  'Toyota > Yaris',
#  'Travel > Greater than $8,000',
#  'Travel > Howard Johnson Buyer Propensity',
#  'Travel Activities > Golfing',
#  'Travel Frequency > Frequent Air Travelers',
#  'Travel Intenders > International Travel',
#  "United States > Children's Products",
#  'United States > Crafts/Hobbies',
#  'United States > Home',
#  'United States > Home Electronics',
#  'United States > Sports',
#  'United States > Urban Dweller',
#  'Vehicle Make > In Market for a Fiat',
#  'Volkswagen > Beetle',
#  'Volkswagen > Golf',
#  'Volkswagen > Jetta',
#  'Volkswagen > Tiguan',
#  'Volkswagen > Touareg',
#  'Volkswagen > Volkswagen Beetle',
#  'Volkswagen > Volkswagen Golf',
#  'Volkswagen > Volkswagen Jetta',
#  'Volkswagen > Volkswagen Tiguan',
#  'Wealth IQ > Net Assets: $362,000-$908,000',
#  'WealthCompleteÂ® HD Total Investable Assets > Asset Range $1,000,000 - $1,999,999',
#  'Wholesale Trade > Wholesale Trade - nondurable goods',
#  'Xennials - The First Millennials (Age 31-41) > Old School Video Gamers',
#  'Xennials - The First Millennials (Age 31-41) > Outdoor Lovers',
#  'Year > 2002'}

# %%
exclusive_interests['ConnectedCar']
# Out:
# {'40-44 > Low Segment',
#  'A/B Test Groups > Group 08',
#  'ABC > $100,000 Pyramid (Game Show)',
#  'Affinity Answers > Movies',
#  'Animation > Peter Rabbit (Movie Franchise)',
#  'Animation > SpongeBob SquarePants Movie (Franchise)',
#  'Animation > Trolls (Franchise)',
#  'Baseball > St. Louis Cardinals',
#  'Baseball > Washington Nationals',
#  'Basketball > Sacramento Kings',
#  'Basketball > Toronto Raptors',
#  'CBS > S.W.A.T. (Drama)',
#  'Communication Channel Preference > Text',
#  'Estimated Household Investable Assets > $100,000 - $249,999',
#  'Genre > Comedy Movie Streamers',
#  'Genre > Crime Movie Streamers',
#  'Genre > Documentary Movie Streamers',
#  'Health & Wellness Shopping > Front of Store Same Location',
#  'Hobbies & Interests > Small Business Owners',
#  'Language > Italian',
#  'Movies > Animation',
#  'Net Worth > $500K - $749.9K',
#  'OTT Network Viewers > Adult Swim Streamers',
#  'OTT Network Viewers > TBS Streamers',
#  'Shows > ABC',
#  'Shows > CBS',
#  'Shows > VH1',
#  'Sports > Basketball',
#  'Studios > 21st Century Fox Streamers',
#  'TV > ABC',
#  'TV > CBS',
#  'TV > VH1',
#  "VH1 > Wild 'n Out (Comedy)"}

# %%
exclusive_interests['Dating']
# Out:
# {'AcquireWeb - Claritas > Auto Ownership',
#  'AcquireWeb - Claritas > Education',
#  'AcquireWeb - Claritas > Employment',
#  'AcquireWeb - Claritas > Healthcare',
#  'AcquireWeb - Claritas > Home Improvement',
#  'AcquireWeb - Claritas > Insurance',
#  'AcquireWeb - Claritas > Lifestage Changes',
#  'AcquireWeb - Claritas > Online Buyer',
#  'AcquireWeb - Claritas > Online Shopper',
#  'AcquireWeb - Claritas > Spending Model',
#  'AcquireWeb - Claritas > Travel',
#  'Active/Interest In > Education Programs',
#  'Active/Interest In > Fitness',
#  'Active/Interest In > Gardening',
#  'Active/Interest In > Health',
#  'Active/Interest In > Home Improvement',
#  'Age of Children in Household > 0-3',
#  'Age of Children in Household > 13-15',
#  'Age of Children in Household > 7-9',
#  'Auto Ownership > Fuel Type',
#  'Auto Ownership > Vehicle Make',
#  'Auto Ownership > Vehicle Style',
#  'Auto Service and Repair > Changes Own Electrical DIY (IMR)',
#  'Auto Service and Repair > Changes Own Fuel Caps DIY (IMR)',
#  'Auto Service and Repair > Changes Own Fuses DIY (IMR)',
#  'Auto Service and Repair > Changes Own Gas Treatment DIY (IMR)',
#  'Auto Service and Repair > Changes Own Sensors DIY (IMR)',
#  'Auto Service and Repair > Chrysler Dealership Auto Service Loyalists (IMR)',
#  'Auto Service and Repair > Ford Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Ford Dealership Auto Service Loyalists (IMR)',
#  'Auto Service and Repair > Honda Dealership Auto Service Loyalists (IMR)',
#  'Auto Service and Repair > Hyundai Dealership Auto Service Defectors (IMR)',
#  'Auto Service and Repair > Kia Dealership Auto Service Loyalists (IMR)',
#  'Auto Service and Repair > Nissan Dealership Auto Service Loyalists (IMR)',
#  'Auto Service and Repair > Pays for Alternator Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Belts and Tensioners Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Brake Fluid Refill Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Engine Tune Up Service DIFM (IMR)',
#  'Auto Service and Repair > Pays for Muffler Repair DIFM (IMR)',
#  'Auto Service and Repair > Pays for Rotating Electrical DIFM (IMR)',
#  'Auto Service and Repair > Pays for Thermostat Repair DIFM (IMR)',
#  'Auto Service and Repair > Prospective Discount Department Store Customer for Auto Parts or Service (IMR)',
#  'Auto Service and Repair > Prospective Jiffy Lube Customer (IMR)',
#  'Auto Service and Repair > Prospective Just Brakes Customer (IMR)',
#  'Auto Service and Repair > Prospective Les Schwab Customer (IMR)',
#  'Auto Service and Repair > Prospective Midas Customer (IMR)',
#  'Auto Service and Repair > Prospective Napa Customer (IMR)',
#  'Auto Service and Repair > Prospective Salvage Yard Customer (IMR)',
#  'Auto Service and Repair > Prospective Tires Plus Customer (IMR)',
#  'Auto Service and Repair > Prospective Tune-Up Specialist Customer (IMR)',
#  'Auto Service and Repair > Repairs Own Radiator Parts DIY (IMR)',
#  'Auto Service and Repair > Repairs Own Spark Plugs DIY (IMR)',
#  'Auto Service and Repair > Replace Own Engine Tune Up DIY (IMR)',
#  'Auto Service and Repair > Shops at Discount Store -Mass Merchandisers for Auto Parts and Service (IMR)',
#  'Auto Service and Repair > Uses Firestone Tires (IMR)',
#  'Auto Service and Repair > Uses Valvoline Oil (IMR)',
#  'Basketball > NBA Super Fan',
#  'Behavior Model > Donor',
#  'Behavior Model > Travel',
#  'Books/Music > Spanish/Latin Listener',
#  'Buyer / Owner > Non-Prestige Makeup',
#  'Car Attitude > Green - Committed to Environment',
#  'Connexions > 44 Leisurely Adopters',
#  'Demographics > Age of Children in Household',
#  'Donor > Contributes Charities',
#  'Donor > Volunteering',
#  'Education > Children Attending College',
#  'Education and Career > Beginning Career',
#  'Education and Career > Job Seekers',
#  'Employment > Job Change',
#  'Employment > Plan To Retire',
#  'Employment Status > Job Seeker',
#  'Entertainment > Books/Music',
#  'Financial > Prospective Progressive Auto Insurance Buyer (Scarborough)',
#  'Financial > Prospective Safe Auto Insurance Buyer (Scarborough)',
#  'First Time Homebuyer > No',
#  'Fitness > Exercise Equipment',
#  'Fitness > Fitness Enthusiast',
#  'Football > College Football Fan',
#  'Football > NFL Fan',
#  'Health > Shops Rite Aid Pharmacy (Scarborough)',
#  "Health > Shops Sam's Club Pharmacy (Scarborough)",
#  'Health Attitude > Brand Name Traditionalist',
#  'Health and Fitness > Fitness',
#  'Healthcare > Healthy Living',
#  'Healthy Living > Health Attitude',
#  'Home Improvement > Retail Shopping',
#  'Household Income > $25,000 - $34,999',
#  'In-Market > Health & Fitness',
#  'In-Market > Health and Fitness',
#  'International > Interest in Learning Foreign Culture',
#  'International > Planning a Foreign Vacation in Next Year',
#  'Length of Residence > 10+ Years',
#  'Life Insurance > Plans to Buy Life Insurance',
#  'Life Stages and Events > Education and Career',
#  'Lifestage Changes > Plan to Purchase 2nd House',
#  'Lifestage Changes > Plan to Purchase Home for First Time',
#  'Music > Listens to Music',
#  'Music > Listens to Pop Music',
#  'Music > Listens to Rock Music',
#  'Number of Adults > 2',
#  'Number of Children in Household > 3',
#  'Online Buyer > Electronics & Gadgets',
#  'Online Buyer > Furniture',
#  'Online Buyer > Outdoor Living',
#  'Online Buyer > Shoes',
#  'Online Shopper > Passionate Deal Seeker',
#  'P$YCLE Premier > 60 Foundational Occupant',
#  'PRIZM Premier > 59 New Melting Pot',
#  'Retail > Not Weekly Grocery Shopper (Scarborough)',
#  'Retail > Plans to Buy Blu-Ray Disc Player (Scarborough)',
#  'Retail > Plans to Buy Computer Laptop (Scarborough)',
#  'Retail > Plans to Buy Furniture (Scarborough)',
#  'Retail > Plans to Buy Major Appliance (Scarborough)',
#  'Retail > Plans to Buy Mattress (Scarborough)',
#  'Retail > Plans to Buy Second Home (Scarborough)',
#  'Retail > Shop at Dollar Tree (Scarborough)',
#  'Retail > Shop at Family Dollar (Scarborough)',
#  'Retail > Shop at Ross Dress (Scarborough)',
#  'Retail > Shops at Albertsons (Scarborough)',
#  'Retail > Shops at Dollar Tree (Scarborough)',
#  'Retail > Shops at Family Dollar (Scarborough)',
#  'Retail > Shops at Gamestop (Scarborough)',
#  'Retail > Shops at Payless Shoesource (Scarborough)',
#  'Retail > Shops at Ross Dress for Less (Scarborough)',
#  'Retail > Sports Equipment and Outdoor Gear',
#  'Retail Shopping > Sears Appliance & Hardware',
#  'Spending Model > Electronics & Gadgets',
#  'Spending Model > Home Decor',
#  'Spending Model > Tools & Automotive',
#  'Sports > Sports Enthusiast',
#  'Sports Equipment and Outdoor Gear > Exercise and Fitness',
#  'Sports Fan > Basketball',
#  'Sports Fan > Soccer Super Fan',
#  'Tech > Average Wireless Phone User',
#  'Tech > Below Average Technology User',
#  'Tech > Bright House Networks Internet Service Subscriber',
#  'Tech > Bright House Networks TV Subscriber',
#  'Tech > Decreased Data Plan on Mobile Phone',
#  'Tech > Has Computer',
#  'Tech > Has Mobile Phone Plan With Unlimited Data',
#  'Tech > Has Portable Game Player',
#  'Tech > Heavy Social Media User',
#  'Tech > Heavy Text Messenger',
#  'Tech > Never Had Landline in Current Residence',
#  'Tech > No TV Because Streaming Internet or Downloads',
#  'Tech > Plays Single Player Video Games',
#  'Tech > Prospective Android Smartphone Buyer',
#  'Tech > Prospective Electronic Reader Buyer',
#  'Tech > Recently Upgraded Cell Phone',
#  'Tech > Straight Talk Cell Phone Service Subscriber',
#  'Tech > Uses Android Smart Phone',
#  'Tech > Visit or Publish to Online Community or Social Network',
#  'Tech > Watch Streaming Video',
#  'Tech > Watched Video Content on Game Console',
#  'Tech > Wireline Service Cord Cutter',
#  'Technology Adoption > Late Majority',
#  'Telco Subscribers > Wireless',
#  'Travel > Frequent Domestic Vacation',
#  'Travel > Frequent Foreign Vacation',
#  'Vehicle Make > Ford',
#  'Vehicle Make > Volkswagen',
#  'Vehicle Style > 2 Door Sedan',
#  'Vehicle Style > Utliity Vehicle',
#  'Wireless > Prepaid Plan Subscriber',
#  'Wireless Switcher > Predicted to Switch from AT&T to Us Cellular',
#  'Wireless Switcher > Predicted to Switch from Boost',
#  'Wireless Switcher > Predicted to Switch from Cricket',
#  'Wireless Switcher > Predicted to Switch from Metropcs',
#  'Wireless Switcher > Predicted to Switch from Postpaid to Prepaid Plan',
#  'Wireless Switcher > Predicted to Switch from Prepaid to Postpaid Plan',
#  'Wireless Switcher > Predicted to Switch to Boost',
#  'Wireless Switcher > Predicted to Switch to Cricket',
#  'Wireless Switcher > Predicted to Switch to Metropcs',
#  'Wireless Switcher > Switchers Carriers Often'}

# %%
exclusive_interests['No-Skill']
# Out:
# {'35-39 > High Segment',
#  'Adherence > Adherence Supplement',
#  'Adherence > Supplement Usage',
#  'Age > 60 - 64',
#  'Age > 70 - 74',
#  'Age > Ages 35-39',
#  'Ailments - Treatments > Dental',
#  'Ailments - Treatments > Weight',
#  'Ailments > Allergies Most Likely',
#  'Ailments > Dental Issues',
#  'Allergies > Allergy Medications',
#  'Allergies > Allergy Sufferers',
#  'Allergies > Sinusitis',
#  'Amazon Prime Originals > The Boys',
#  'AmeriLINK > AmeriLINK Life Event Triggers',
#  'AmeriLINK CPG Categories > Baby Products',
#  'AmeriLINK CPG Categories > Baking Supplies',
#  'AmeriLINK CPG Categories > Gravies and Sauces',
#  'AmeriLINK CPG Categories > Jellies, Jams and Nut Butters',
#  'AmeriLINK CPG Categories > Pet Products',
#  'AmeriLINK CPG Categories > Pickles and Olives',
#  'AmeriLINK CPG Categories > Seasonings and Spices',
#  'AmeriLINK Consumer Buying Behavior > Retail & Product Brands',
#  'AmeriLINK Life Event Triggers > New Movers',
#  'Baby Products > Baby Foods, Beverages and Snacks Purchasers',
#  'Bakery Products > Cakes, Pies and Desserts Purchasers',
#  'Baking Supplies > Baking Ingredients Purchasers',
#  'Baking Supplies > Baking Mixes Purchasers',
#  'Baking Supplies > Gelatin, Flans and Pudding Mixes Purchasers',
#  'Baking Supplies > Pancake and Waffle Mixes Purchasers',
#  'Beverages > Coffee Purchasers',
#  'Beverages > Juices and Non Carbonated Drinks Purchasers',
#  'Beverages > Tea Purchasers',
#  'Black Friday > Black Friday Shoppers – Shopping for Kids',
#  'Brand Names J - M > Lancome',
#  'Branded Data > StatSocial',
#  'Breakfast Items > Hot Cereals Purchasers',
#  'Breakfast Items > Toaster Pastries Purchasers',
#  'Candies and Gums > Gums and Mints Purchasers',
#  'Condiments > Mayonnaise Purchasers',
#  'Condiments > Mustards Purchasers',
#  'Condiments > Relish Purchasers',
#  'Condiments > Vinegars Purchasers',
#  'Cooking and Specialty Oils > Cooking Oils and Sprays Purchasers',
#  'Cyber Monday > Cyber Monday Shoppers – Shopping for Jewelry & Accessories',
#  'Cyber Monday > Cyber Monday Shoppers – Shopping for Kids',
#  'Cyber Monday > Cyber Monday Shoppers – Shopping for Men’s Apparel',
#  'Cyber Monday > Cyber Monday Shoppers – Shopping for Women’s Apparel',
#  'Dairy and Alternatives > Cheese Purchasers',
#  'Dairy and Alternatives > Cream Cheese Purchasers',
#  'Dairy and Alternatives > Ice Cream, Pops and Frozen Novelties Purchasers',
#  'Dairy and Alternatives > Ricotta, Cottage Cheese and Sour Cream Purchasers',
#  'Dairy and Alternatives > Yogurt Purchasers',
#  'Demographics & Segmentation > Occupation',
#  'Dental > Gingivitis',
#  'Dressings, Dips and Salsas > Dips Purchasers',
#  'Dressings, Dips and Salsas > Salsa Purchasers',
#  'Employer Sponsored Health Insurance > Employer Sponsored Health Insurance Likely',
#  'Estimated Household Income > $75K-$99.9K',
#  'Extraversion > Excitement-Seeking',
#  'Eye & Vision > Corrective Lense Wearers',
#  'Family Position > Wife',
#  'Fruits > Fresh Fruits Purchasers',
#  'Fruits > Frozen and Refrigerated Fruits Purchasers',
#  'General Merchandise > Home Batteries and Chargers Purchasers',
#  'Gravies and Sauces > All Other Sauces Purchasers',
#  'Gravies and Sauces > Barbeque Sauces Purchasers',
#  'Gravies and Sauces > Cooking Sauces Purchasers',
#  'Gravies and Sauces > Gravies Purchasers',
#  'Gravies and Sauces > Hot Sauces Purchasers',
#  'Gravies and Sauces > Pasta Sauce Purchasers',
#  'Gravies and Sauces > Pizza Sauces Purchasers',
#  'Health Choices / Lifestyle > Exercise',
#  'Health Ranks > Ailments',
#  'Health and Wellness > Analgesics Purchasers',
#  'Health and Wellness > Cold, Cough and Flu Care Purchasers',
#  'Health and Wellness > Diet, Nutritional Supplements and Vitamins Purchasers',
#  'Health and Wellness > Digestive Remedies Purchasers',
#  'Health and Wellness > First Aid Supplies Purchasers',
#  'Holiday/Christmas Shoppers > Jewelry & Accessories',
#  'Home Value > $201K-$300K',
#  'Household Care Products > Air Fresheners and Candles Purchasers',
#  'Household Care Products > Household Cleaning Supplies Purchasers',
#  'IBM Watson Personality Insights > Needs',
#  'IBM Watson Personality Insights > Personality',
#  'IBM Watson Personality Insights > Values',
#  'Insurance Responder Index > Health Insurance Responder (18-64) - Likely',
#  'Insurance/Financial Behaviors > Employer Sponsored Health Insurance',
#  'International Specialty Products > Asian Specialties Purchasers',
#  'Jellies, Jams and Nut Butters > Nut Butters Purchasers',
#  'Meats, Seafood and Alternatives > Deli Meats Purchasers',
#  'Meats, Seafood and Alternatives > Poultry Purchasers',
#  'Meats, Seafood and Alternatives > Seafood Purchasers',
#  'Move Date > Last 151 - 180 Days',
#  'Needs > Curiosity',
#  'Needs > Harmony',
#  'Net Worth > $75K - $99.9K',
#  'New Movers > Move Date',
#  'OTT Exclusive Content Viewers > Amazon Prime Originals',
#  'OTT Network Viewers > Comedy Central Streamers',
#  'Occupation > Business Owner',
#  'Openness > Emotionality',
#  'Paper, Plastic and Storage > Coffee and Tea Filters Purchasers',
#  'Paper, Plastic and Storage > Cups, Plates, Napkins and Utensils Purchasers',
#  'Paper, Plastic and Storage > Food Storage Purchasers',
#  'Paper, Plastic and Storage > Paper Towels Purchasers',
#  'Personal Care and Beauty Products > Bath Care Purchasers',
#  'Personal Care and Beauty Products > Deodorants, Body Powders and Mists Purchasers',
#  'Personal Care and Beauty Products > Oral Care Purchasers',
#  'Personal Care and Beauty Products > Shaving Care Purchasers',
#  'Personality > Extraversion',
#  'Personality > Openness',
#  'Pet Products > Cat Foods and Treats Purchasers',
#  'Pet Products > Pet Litter and Waste Supplies Purchasers',
#  'Pickles and Olives > Olives Purchasers',
#  'Pickles and Olives > Pickles and Pickled Vegetables Purchasers',
#  'Prepared Foods, Deli and Meal Mixes > Breakfast Foods Purchasers',
#  'Prepared Foods, Deli and Meal Mixes > Pizza Purchasers',
#  'Prepared Foods, Deli and Meal Mixes > Sandwiches and Wraps Purchasers',
#  'Prepared Foods, Deli and Meal Mixes > Soups and Broths Purchasers',
#  'Retail & Product Brands > Brand Names J - M',
#  'Seasonings and Spices > All Other Seasonings and Spices Purchasers',
#  'Seasonings and Spices > Salt Purchasers',
#  'Seasonings and Spices > Seasoning Mixes Purchasers',
#  'Snacks, Nuts and Bars > Gelatin, Flans and Fruit Snacks Purchasers',
#  'Snacks, Nuts and Bars > Jerky and Meat Snacks Purchasers',
#  'Snacks, Nuts and Bars > Nuts, Seeds and Trail Mixes Purchasers',
#  'Snacks, Nuts and Bars > Salty Snacks, Pretzels and Chips Purchasers',
#  'Snacks, Nuts and Bars > Snack Cereal and Protein Bars Purchasers',
#  'StatSocial > IBM Watson Personality Insights',
#  'Studios > Amazon Studios Streamers',
#  'Studios > Sony Streamers',
#  'Values > Openness to Change',
#  'Vegetables > Frozen and Refrigerated Vegetables Purchasers',
#  'Weight > Weight (Individual)'}

# %%
exclusive_interests['Amazon-Only']
# Out:
# {'AFS Buckets > 3',
#  'Account Holders > College Savings',
#  'Acura > Acura RDX',
#  'Acura > Acura TL',
#  'Acura > Acura TLX',
#  'AdAdvisor - Private > AdAdvisor Consumer Audiences',
#  'AdAdvisor Consumer Audiences > Web Browsing',
#  'AdAdvisor by Neustar > Life Events',
#  'Adstra (formerly ALC) > Wealth',
#  'Affluence Segments > Giving Back',
#  'Age of Children in Household > 16-17',
#  'All Categories Frequency > Number of Credit Purchases Total: 1-2',
#  "America's Wealthiest > (A) - Top 10%",
#  'Apparel > Ann Taylor Buyer Propensity',
#  'Apparel > Asics Buyer Propensity',
#  'Apparel > Dolce Vita Buyer Propensity',
#  'Apparel > Foot Locker Buyer Propensity',
#  'Apparel > Guess Buyer Propensity',
#  'Apparel > Lilly Pulitzer Buyer Propensity',
#  'Apparel > Rent the Runway Buyer Propensity',
#  'Apparel > Stride Rite Buyer Propensity',
#  'Apparel > Timberland Buyer Propensity',
#  'Apparel > Tommy Bahama Buyer Propensity',
#  'Apparel > Vera Bradley Buyer Propensity',
#  'Apple > iPhone',
#  'Art & Entertainment > Books & Literature',
#  'Audi > A3',
#  'Audi > A4',
#  'Audi > Audi A3',
#  'Audi > Audi A4',
#  'Audi > Audi A5',
#  'Audi > Audi A7',
#  'Audi > Audi A8',
#  'Audi > Audi Q3',
#  'Audi > Audi Q5',
#  'Audi > Audi Q7',
#  'Audi > Q5',
#  'Auto Enthusiasts > Car Culture and Gearheads',
#  'Automotive > Car Culture',
#  'Automotive Owners > Own a Honda',
#  'Average Household Income > $150000+',
#  'BMW > BMW 2 Series',
#  'BMW > BMW 3 Series',
#  'BMW > BMW 4 Series',
#  'BMW > BMW 5 Series',
#  'BMW > BMW 6 Series',
#  'BMW > BMW 7 Series',
#  'BMW > BMW X1',
#  'BMW > BMW X3',
#  'BMW > BMW X5',
#  'BMW > BMW X6',
#  'Banking Account Type > Savings',
#  'Beauty Products > Mascara',
#  'Beverages > Soda',
#  'Big Box Retail > Office Max Buyer Propensity',
#  'Boating > Sailing',
#  'Body Style > SUV',
#  'Body Style > Utility',
#  "Brands > Dick's Sporting Goods",
#  'Brands > Diet Coke',
#  'Brands > Frigidaire',
#  'Brands > Home Depot',
#  "Brands > Kohl's",
#  'Brands > Milk Bone',
#  'Brands > Nordstrom Rack',
#  'Brands > Super Target',
#  'Brands > Target',
#  'Brands > Tostitos',
#  'Brands > Utz',
#  'Browser Activity > Education',
#  'Business & Finance > Investment Banking',
#  'Business > C-Level Executives',
#  'Business At Home/Cottage > Yes',
#  'Business Employee Size > 1 - 4 Employees',
#  'Business Executives > Business At Home/Cottage',
#  'Business Executives > Business Employee Size',
#  'Business Executives > Business Sales Volume',
#  'Business Executives > Business Type/Holding',
#  'Business Executives > SIC Division/Type of Business',
#  'Business Sales Volume > $1,000,000 - $2,499,999',
#  'Business Type/Holding > Private',
#  'Buyers > Bakeware & Cooking Products',
#  'Buyers > High-End Gadgets',
#  "CPG > Ben & Jerry's",
#  'CPG > Capri Sun',
#  'CPG > Lean Cuisine',
#  'CPG > Pepto-Bismol',
#  'Cadillac > Cadillac Escalade',
#  'Cadillac > Cadillac XT5',
#  'Caregiver by Caregivee HHI > Caregivee HHI $200,000-$499,999',
#  'Celebrities > Katy Perry',
#  'Celebrities > Taylor Swift',
#  'Charities and Non-Profits > Veterans',
#  'Chevrolet > Chevrolet Corvette',
#  'Chevrolet > Chevrolet Impala',
#  'Chevrolet > Chevrolet Silverado 1500',
#  'Chevy > ODC Experian In Market Ford Mach E _Proxy1',
#  'Chevy > ODC Experian In Market Ford Mach E _Proxy1a',
#  'Children in Household > No',
#  'Class > Full Size SUV',
#  'College Teams > Michigan Wolverines',
#  'College Teams > Villanova Wildcats',
#  'Companies by Location > West South Central Region',
#  'Company Industry > Financial and Insurance Services',
#  'Composite Segments (Audience Clusters) > Sports & Fitness Buffs',
#  'Consumer Behavior > At-Home: Families at Home (Kids 13+)',
#  'ConsumerSpend Electronics > $1,000-$2,499',
#  'Continuity/Subscriptions > Dollars Spent: Mid-Level Spender',
#  'Convenience & Gas > Circle K Buyer Propensity',
#  'Coupons > Free Products, Coupons',
#  'Dedication Spectrum > Mid-core Male Gamers',
#  'Delivery > Fast Food Delivery Users',
#  'Demographics > College Graduates',
#  'Demographics > Home Value $300-499k',
#  'Demographics > Income 150k+',
#  'Demographics > Length of Residence 6-9 years',
#  'Demographics > Management/Professional Occupations',
#  'Demographics > Presence of Children Age 4-7',
#  'Demographics > Presence of Children by Age and Gender',
#  'Demographics > White Collar Occupations',
#  'Department/Discount/Warehouse Stores > Costco',
#  'Device > Cable/Satellite Box',
#  'Discretionary Spending > $75,000 - $99,999',
#  'Downloaded/Streaming > Device',
#  'Downloaded/Streaming > Movies',
#  'Downloaded/Streaming > Netflix - Last 30 Days',
#  'Eating Styles > Healthy',
#  'Ecommerce > Mercari Buyer Propensity',
#  'Ecommerce > Snapfish Buyer Propensity',
#  'Economic Cohorts > $200K+ Income, Age - Working Years (35-54), Careers First - City Singles - N65',
#  'Education > All Graduates Major in Business',
#  'Education > All Graduates Major in Health Science',
#  'Education > All Undergraduates Major in Hospitality, Tourism & Travel',
#  'Education > Colleges',
#  'Education > Some Graduate School',
#  "Education Level Census > Bachelor'S Degree",
#  'Employed Full or Part Time > Employed Full Time',
#  'Employment > Educator',
#  'Employment > Employment Industry',
#  'Employment Industry > Finance, Insurance, & Accounting',
#  'Employment Status > Employed Full or Part Time',
#  'Estimated Home Value (USD) > $500,000 - $799,000',
#  'Estimated Home Value (USD) > $500,000 - $799,999',
#  'Estimated Household Income (USD) > $150,000 - $249,999',
#  'Estimated Net Worth (USD) > $500,000 - $999,999',
#  'Estimated Net Worth (USD) > $500,000 – $999,999',
#  'Estimated Net Worth > $2,000,000 - $3,999,999',
#  'Estimated Net Worth > $2,000,000 to $3,999,999',
#  'Estimated Net Worth > Greater than $499,999',
#  'Executive Title > Owner',
#  'Experian - Private > Housing Attributes',
#  'Experian - Private > MMGY',
#  'FCA > Experian In Market Buick LaCrosse_V2',
#  'FCA > Experian In Market Chevrolet Camaro_V2',
#  'FCA > Experian In Market Nissan Maxima_V2',
#  'Family Composition > Working Woman',
#  'Family Member Age > 40-49',
#  'Family Member Age > Ages 40-49',
#  'Fiat > Fiat 500c',
#  'Finance > Investment Banking',
#  'Financial Attributes > Wealth Decile',
#  'Financial Cohorts > $1MM+ Assets, Age 35-54, Major Metro - High-Powered Careers - Investors - J35',
#  'Financial Mobility > Future Income Range $250,000 and greater',
#  'Financial and Insurance Services > Investment Banking',
#  'Food & Drink > Desserts & Baking',
#  'Food & Drink > Health Or Lowfat Cooking',
#  'Food & Drugstore > GNC Buyer Propensity',
#  'Food & Drugstore > HEB Grocery Buyer Propensity',
#  'Food and Drink > Eating Styles',
#  'Ford > Edge',
#  'Ford > Escape',
#  'Ford > Explorer',
#  'Ford > Ford Escape',
#  'Ford > Ford Expedition',
#  'Ford > Ford Explorer',
#  'Ford > Ford F150',
#  'Gender > Affluent Men',
#  'Genres > Sci-Fi and Fantasy',
#  'Grocery > Nutritional Snacks',
#  'Grocery Stores > Recent Grocery Visitor - Kroger',
#  'Group A: Power Elite > A03 - Kids and Cabernet',
#  'HHI: Greater than $125,000 > HHI: $200,000-$249,999',
#  'Health & Wellbeing > Fitness & Exercise',
#  'Health & Wellbeing > Weight Loss',
#  'Health / Beauty & Cosmetics > Doctor On Demand Buyer Propensity',
#  'Health / Beauty & Cosmetics > Estee Lauder Buyer Propensity',
#  'Health Insurance > Flexible Spending Account',
#  'High Net Worth Consumers > (B) - $1,000,000-$1,999,999',
#  'Highest Level of Education > Graduate Degree',
#  'Highest Level of Education > Graduated College or More',
#  'Highest Level of Education > Some Graduate School',
#  'Hobbies & Interests > Cooking for Fun',
#  'Hobbies & Interests > Dining Out - Not Fast Food',
#  'Hobbies & Interests > Fitness Walking',
#  'Hobbies & Interests > Jogging/Running',
#  'Hobbies & Interests > Workout at Home',
#  'Holiday Shoppers > Teen Gifts',
#  'Home & Family > Gardening',
#  'Home & Household Goods > HomeGoods Buyer Propensity',
#  'Home & Household Goods > Pottery Barn Buyer Propensity',
#  'Home & Household Goods > Sleep Number Buyer Propensity',
#  'Home & Household Goods > Tuesday Morning Buyer Propensity',
#  'Home Equity > $120,000-$139,999',
#  'Home Ownership > Own House',
#  'Home Ownership > Own Primary Residence',
#  'Home Purchased Years Ago > 5-8 Years',
#  'Home Value > $500,000-$749,999',
#  'Home Value > $600,001 to $800,000',
#  'Home Value > (B) - $500,000 - $749,999',
#  'Home Value Range > $400 - $450k',
#  'Homeowner Insurance > State Farm',
#  'Honda > Accord',
#  'Honda > Honda CR V',
#  'Honda > Honda Insight',
#  'Household Composition > Presence of 2 or more Adult Females',
#  'Household Income > $175,000-$199,999',
#  'Household Income > $250,000+',
#  'Household Income > (C) - $200,000 - $250,000',
#  'Household Income Range > $140,000-$159,999',
#  'Important Life Events > Stay at Home Parents',
#  'In Market - Body Styles > Exotic',
#  'In Market - Body Styles > Full-Size Van',
#  'In Market - Body Styles > Luxury SUV',
#  'In Market - Fuel > CUV SUV',
#  'In Market - Fuel > Electric',
#  'In Market - Fuel > Used Electric',
#  'In Market - Lease > Luxury Lease',
#  'In Market - Make and Models > Acura',
#  'In Market - Make and Models > BMW X2',
#  'In Market - Make and Models > Buick',
#  'In Market - Make and Models > Cadillac',
#  'In Market - Make and Models > Genesis',
#  'In Market - Make and Models > Infiniti',
#  'In Market - Make and Models > Jaguar',
#  'In Market - Make and Models > Land Rover',
#  'In Market - Make and Models > Lexus',
#  'In Market - Make and Models > Lincoln',
#  'In Market - Make and Models > Mercedes-Benz',
#  'In Market - Make and Models > Mini',
#  'In Market - Make and Models > Porsche',
#  'In Market - Make and Models > Subaru',
#  'In Market - Make and Models > Tesla',
#  'In Market - Make and Models > Volkswagen',
#  'In Market - Make and Models > Volvo',
#  'In Market - Switch to > Heavy Duty (HD) Pickup',
#  'In Market - Switch to > Jeep',
#  'In Market - Vehicle Price > 75K+',
#  'In Market > Organic Food Shoppers',
#  'In Market > Whole Foods Shoppers',
#  'In Store Shoppers > Personal Health',
#  'In Store Shoppers > Shoes',
#  'In-Market > Arts & Crafts',
#  'In-Market > Arts and Crafts',
#  'In-Market > Indicators',
#  'In-Market > Retail Apparel - Working Families',
#  'In-Market Segments > In-Market for New SUV',
#  'In-Market Segments > Insurance',
#  'In-Market Segments > Multi-Car Owner In-Market for New Car',
#  'Income 360 > Income Range $250,000 and above',
#  'Income 360 > Total Income $250,000 and Above',
#  'Indicators > Utility',
#  'Infiniti > Infiniti Q50',
#  'Infiniti > Infiniti Q60',
#  'Infiniti > Infiniti QX30',
#  'Infiniti > Infiniti QX50',
#  'Infiniti > Infiniti QX60',
#  'Infiniti > Infiniti QX80',
#  'Intenders > Business Magazines',
#  'Intenders > Electronics as a Gift',
#  'Intenders > Furniture & Rugs',
#  'Intenders > Kitchen Items',
#  'Interest (Affinity) > College Savings',
#  'Interest (Affinity) > Eating Styles',
#  'Interest > Golf Enthusiasts',
#  'Interest > Riding Horses',
#  'Interests > Auto Parts',
#  'Interests > Boating',
#  'Interests > Boating/Sailing',
#  'Interests > College Basketball Enthusiast',
#  'Interests > College Football Bowls',
#  'Interests > Cooking, Gourmet',
#  'Interests > Outdoor',
#  'Interests > Travel Vacation',
#  'Interests > Travel, Domestic',
#  'Interests > Travel, International',
#  'Investable Assets > (B) - $500,000 - $999,999',
#  'Investable Assets > Tier 2',
#  'Jaguar > Jaguar F Pace',
#  'KIA > Kia Stinger',
#  'Kids Products > AbcMouse Buyer Propensity',
#  'Land Rover > Land Rover Discovery Sport',
#  'Land Rover > Land Rover Range Rover',
#  'Land Rover > Land Rover Range Rover Evoqe',
#  'Land Rover > Land Rover Range Rover Sport',
#  'Leisure Activities/Hobbies > Golf Lover',
#  'Leisure and Vacation Travelers > Tourism and Sight Seeing',
#  'Length Of Residence > 6 Years',
#  'Length Since Last Home Loan (Months) > 90 to 119 months',
#  'Length Since Last Home Loan > 90-120 Months',
#  'Lexus > Lexus ES',
#  'Lexus > Lexus GS',
#  'Lexus > Lexus GX',
#  'Lexus > Lexus LX',
#  'Lexus > Lexus NX',
#  'Life Events > Child Entered College',
#  'Life Events > Expect to Make Major Home Improvement',
#  'Life Events > Leased Or Bought New Car Or Light Truck',
#  'Lifestage > High Income Families',
#  'Lifestyle/Interest > Home Decor & Interior Design Enthusiasts',
#  'Lifestyle/Interest > Luxury Home Owners',
#  'Likely Donors > Veterans Causes',
#  'Lincoln > Lincoln MKZ',
#  'Lincoln > Lincoln Navigator',
#  'Locations > Domestic (United States)',
#  'Luxury Travelers > Domestic',
#  'Luxury Travelers > International',
#  'MLB Teams > NY Yankees',
#  'MMGY > Meritage Affluent Traveler',
#  'Makes & Models > Acura',
#  'Makes & Models > Honda',
#  'Makes > Volvo',
#  'Makes and Models > Tesla',
#  'Makes and Models > Volvo',
#  'Manufacturing > Computers',
#  'Manufacturing > Industrial & Commercial Machinery',
#  'Manufacturing > Lumber & Wood Products',
#  'Mazda > Mazda CX 5',
#  'Mazda > Mazda CX 9',
#  'Media & Entertainment > OurTime Buyer Propensity',
#  'Media & Entertainment > Scholastic Buyer Propensity',
#  'Median Home Value > $600,000-$699,999',
#  'Mercedes-Benz > MB CLA Class',
#  'Mercedes-Benz > MB S Class',
#  'Mercedes-Benz > Mercedes-Benz C Class',
#  'Mercedes-Benz > Mercedes-Benz CLA Class',
#  'Mercedes-Benz > Mercedes-Benz E Class',
#  'Mercedes-Benz > Mercedes-Benz GLA Class',
#  'Mercedes-Benz > Mercedes-Benz GLC Class',
#  'Mercedes-Benz > Mercedes-Benz GLE Class',
#  'Mercedes-Benz > Mercedes-Benz S Class',
#  'Mobile Devices > Mobile Phone Buyer',
#  'Mobile Location Audiences > Female Employees',
#  'Mobile Location Audiences > Grocery Stores',
#  'Mobile Plan Type > Business/Corporate Plan',
#  'Mobile Plan Type > Family Plan',
#  'Mobile Service Provider > Mobile Phone Buyer - T-Mobile',
#  'Mosaic > Group A: Power Elite',
#  'Movers > Family',
#  'Movies > Comedy',
#  'Movies > Harry Potter',
#  'Movies > Science Fiction and Fantasy',
#  'Movies > Scifi Movie Buff',
#  'Movies > Spider Man',
#  'Movies > Transformers',
#  'Movies > Wonder Woman',
#  'Multibuyer Behaviors > Magazine Multibuyers',
#  'N/A > NCS+CNC-026+3P_Clean & Clear_Acne_2020_TA-In Category_558992_CP_ACQ_GM_BE-AB_CE-AB_T-R52W -PD558992',
#  'NFL > Carolina Panthers',
#  'NFL > Houston Texans',
#  'NFL > Seatlle Seahawks',
#  'NFL > Washington Redskins',
#  'Narrow Age > 50-54',
#  'Net Assets Score > $750,000-$999,999',
#  'News > National News',
#  'News Sites > VisitFoxnews.com in the Last 30 Days',
#  'Nissan > Nissan Altima',
#  'Nissan > Nissan Maxima',
#  'No > Empty Nester',
#  'Number of Children > One or More',
#  'Number of Children in Household > 3 or More',
#  'Occupation > Management/Business & Financial Operations',
#  'Online Behaviors > Air Travel',
#  'Online Behaviors > Gardening',
#  'Outdoor Activities > Boating & Sailing',
#  'Outdoor Activities > Horseback Riding (Equestrian)',
#  'Overall Investable Assets > Top 2 - 5%',
#  'Overall Investable Assets > Top 2% - 5%',
#  'Own a Honda > Own a Honda Accord',
#  'Ownership - Body Styles > Exotic',
#  'Ownership - Body Styles > Luxury SUV',
#  'Ownership - Make and Models > Acura',
#  'Ownership - Make and Models > Alfa Romeo',
#  'Ownership - Make and Models > Alfa Romeo Giulia',
#  'Ownership - Make and Models > Alfa Romeo Stelvio',
#  'Ownership - Make and Models > Audi',
#  'Ownership - Make and Models > Audi SQ5',
#  'Ownership - Make and Models > Infiniti',
#  'Ownership - Make and Models > Jaguar',
#  'Ownership - Make and Models > Jaguar F Pace',
#  'Ownership - Make and Models > Kia Stinger',
#  'Ownership - Make and Models > Land Rover',
#  'Ownership - Make and Models > MB G Class',
#  'Ownership - Make and Models > Porsche',
#  'Ownership - Make and Models > Porsche 911',
#  'Ownership - Make and Models > Porsche Cayenne',
#  'Ownership - Make and Models > Porsche Macan',
#  'Ownership - Make and Models > RAM',
#  'Ownership - Make and Models > Tesla',
#  'Ownership - Make and Models > Tesla Model 3',
#  'Ownership - Make and Models > Tesla Model S',
#  'Ownership - Make and Models > Tesla Model X',
#  'Ownership - Make and Models > Volvo XC40',
#  'Ownership - Switch to > Nissan',
#  'Ownership - Switch to > Van',
#  'Parents > Parents of Entertainment Kids',
#  'Past Purchases > Travel',
#  'Pay Method > Pay by American Express',
#  'Personal Finance > Homeowner Insurance',
#  'Personal Finance > Invest in 529 College Savings',
#  'Pets > Brands',
#  'Porsche > Porsche 911',
#  'Porsche > Porsche Cayenne',
#  'Porsche > Porsche Macan',
#  'Presence of Children by Age and Gender > Age 12 to 17',
#  'Proctor & Gamble > Cascade',
#  'Products & Services Propensities > Family Restaurant Visitors - Propensity',
#  'Products & Services Propensities > Safety / Security Insurance Buyers - Propensity',
#  'Products > Air Travel',
#  'Professional/Technical > Healthcare Practice, Technical',
#  'Professionals by Department/Functional Area > Sales & Business Development',
#  'Professionals by Title/Job Function > C-Level/C-Suite Professionals',
#  'Professionals by Title/Job Function > Owner/Partner',
#  'Profitability > High profitability - Tier 1',
#  'Purchases > Automotive Tools & Gadgets',
#  'Purchases > Lawn & Garden',
#  'Quick Service Restaurants (QSRs) > Burger King',
#  "Quick Service Restaurants (QSRs) > Popeye's",
#  'RAM > RAM 2500',
#  'Reading > Interior Decorating',
#  'Remote Business Decision Makers & Influencers > Prefers Case Study Marketing Content',
#  'Remote Business Decision Makers & Influencers > Sales & Marketing Decision Makers & Influencers',
#  'Restaurants & Dining > Bonefish Grill Buyer Propensity',
#  'Restaurants & Dining > Waffle House Buyer Propensity',
#  'SIC Division/Type of Business > Finance, Insurance, and Real Estate',
#  'Small Business Assets > Small Business Asset Range $50,000 - $99,999',
#  'Social Networks > Twitter Influencer',
#  'Soda > Diet',
#  'Special Events > Kentucky Derby',
#  'Sporting Goods > Finish Line Buyer Propensity',
#  'Sports & Recreation > Water Sports',
#  'Sports > Horse Racing Fans',
#  'State > TX',
#  'TeamOne (Lexus) > Experian_Own_A7',
#  'TeamOne (Lexus) > Experian_Own_A8',
#  'TeamOne (Lexus) > Experian_Own_Model_S',
#  'Technology & Computing > Internet Technologies',
#  'Technology & Computing > Mobile Plan Type',
#  'Technology & Computing > Wearables',
#  'Tesla > Tesla Model 3',
#  'Tesla > Tesla Model S',
#  'Tesla > Tesla Model X',
#  'Toyota > Toyota Sienna',
#  'Toyota > Toyota Tundra',
#  'Travel > Domestic',
#  'Travel > Great America Buyer Propensity',
#  'Travel > JetBlue Buyer Propensity',
#  'Travel > MGM Grand Hotel & Casino Buyer Propensity',
#  'Travel > RV',
#  'Travel > Regent Seven Seas Buyer Propensity',
#  'Travel > Seabourn Buyer Propensity',
#  'Travel > Travelzoo Buyer Propensity',
#  'Travel > Westin Hotel Buyer Propensity',
#  'Travel Activities > Biking',
#  'Travel Activities > Spa',
#  'Travel Activities > Water Sports',
#  'Travel Preference > Eco-sustainable Travel',
#  'Vacation Activities > Fishing',
#  'Vacation Activities > Go To The Beach',
#  'Vacation Activities > Sightseeing',
#  'Vacation Activities > Snow Skiing or Snow Boarding',
#  'Vacation Activities > Theme Parks',
#  'Vacation Activities > Water Sports',
#  'Vehicle Make > Honda',
#  'Vehicle Make > In Market for a Volvo',
#  'Vehicle Use > Waze Users',
#  'Volvo > Volvo XC-Series',
#  'Volvo > Volvo XC40',
#  'Volvo > Volvo XC60',
#  'Volvo > Volvo XC90',
#  'Volvo > XC60',
#  'Volvo > XC90',
#  'Volvo XC-Series > Volvo XC90',
#  'Water Sports > Boating, Kayaking & Canoeing',
#  "Wealth > America's Wealthiest",
#  'Wealth > High Net Worth Consumers',
#  'Wealth > Household Income',
#  'Wealth > Investable Assets',
#  'Wealth > Lifestyle/Interest',
#  'Wealth > Luxury Travelers',
#  'Wealth > Millionaires',
#  'Wealth Decile > 1st (Greatest Wealth)',
#  'WealthCompleteÂ® HD Total Investable Assets > Asset Range $2,000,000 - $2,999,999',
#  'Wearables > HH Has At Least 1 Wearable Device',
#  'Wearables > Use App/Site To Track Calories/ Exercise',
#  'Wearables > Used Wearable Fitness Health Tracker in the Last 12 Months',
#  'Web Browsing > News Sites',
#  'Working From Home > Remote Workers Likely to Enjoy Video Games',
#  'unruly_cultural_insecure1P_US > 10-15%'}
